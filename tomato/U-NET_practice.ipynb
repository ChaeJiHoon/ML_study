# %%
import cv2
import json
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Cropping2D, Dropout,BatchNormalization, Activation
from tensorflow.keras.models import Model
from skimage.transform import resize
from keras.layers import Conv2DTranspose
from keras.preprocessing.image import img_to_array, load_img




img_directory = 'E:\\Unet\\만개꽃_축소이미지'
json_directory = 'E:\\Unet\\만개꽃_축소JSON'

image_files = [os.path.join(img_directory, file) for file in os.listdir(img_directory) if file.endswith('.png')][:300]
json_files = [os.path.join(json_directory, file.replace('.png', '.json')) for file in os.listdir(img_directory) if file.endswith('.png')][:300]

print(f"Number of image files: {len(image_files)}")
print(f"Number of json files: {len(json_files)}")

for image_file, json_file in zip(image_files, json_files):
    image = Image.open(image_file)
    image = np.array(image)

    if image is None:
        print(f"Cannot load image: {image_file}")
        continue

    with open(json_file, 'r') as f:
        data = json.load(f)

    original_size = (data['imageWidth'], data['imageHeight'])

    # 세그멘테이션 이미지 초기화 (모든 픽셀 값이 0인 이미지)
    segmentation = np.zeros((original_size[1], original_size[0]), dtype=np.uint8)

    shapes = data['shapes']
    
    # points로 가져온 좌표 안쪽은 모두 1로 라벨링 하는 코드
    for shape in shapes:
        points = np.array(shape['points'], dtype=np.int32)
        cv2.fillPoly(segmentation, [points], 1)
    
    # 
    new_image_path = os.path.join("E:/Unet/만개꽃/", os.path.split(image_file)[1].replace('.png', '_seg.png'))

    img_pil = Image.fromarray(segmentation * 255)  # 0과 1로 이루어진 이미지를 0과 255로 변환
    img_pil.save(new_image_path)

    # 세그멘테이션 이미지를 화면에 출력
    plt.imshow(segmentation, cmap='gray')
    plt.show()
# Out:
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Number of image files: 300
# Number of json files: 300

# %%
def ConvBlock(filters, inputs):
    x = Conv2D(filters, (3, 3), padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(filters, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

# %%
def create_model(input_shape):
    inputs = Input(input_shape)

    conv1 = ConvBlock(64, inputs)
    drop1 = Dropout(0.2)(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(drop1)

    conv2 = ConvBlock(128, pool1)
    drop2 = Dropout(0.2)(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(drop2)

    conv3 = ConvBlock(256, pool2)
    drop3 = Dropout(0.2)(conv3)

    # Bridge
    bridge = ConvBlock(512, drop3)

    up4 = Conv2DTranspose(128, 2, strides=(2, 2), padding='same')(bridge)
    merge4 = concatenate([drop2, up4], axis=3)
    conv4 = ConvBlock(128, merge4)
    drop4 = Dropout(0.2)(conv4)

    up5 = Conv2DTranspose(64, 2, strides=(2, 2), padding='same')(drop4)
    merge5 = concatenate([drop1, up5], axis=3)
    conv5 = ConvBlock(64, merge5)
    drop5 = Dropout(0.2)(conv5)

    conv6 = Conv2D(2, 3, activation='relu', padding='same', kernel_initializer='he_normal')(drop5)
    conv7 = Conv2D(1, 1, activation='sigmoid')(conv6)

    model = Model(inputs=inputs, outputs=conv7)

    return model

# %%
img_directory = 'E:\\Unet\\만개꽃_축소이미지'
segmentation_directory = 'E:/Unet/만개꽃/'

image_files = [os.path.join(img_directory, file) for file in os.listdir(img_directory) if file.endswith('.png')]
segmentation_files = [os.path.join(segmentation_directory, file.replace('.png', '_seg.png')) for file in os.listdir(img_directory) if file.endswith('.png')]

# 학습 데이터와 테스트 데이터로 나누는 부분
image_train_files = image_files[:80]
segmentation_train_files = segmentation_files[:80]
image_test_files = image_files[80:100]
segmentation_test_files = segmentation_files[80:100]

# 이미지와 세그멘테이션 레이블의 크기를 조정할 크기
target_size = (480, 272)

def load_data(image_files, segmentation_files, target_size):
    images = []
    labels = []

    for image_file, segmentation_file in zip(image_files, segmentation_files):
        # 이미지 로드
        image = load_img(image_file, target_size=target_size)
        image = img_to_array(image)

        # 세그멘테이션 이미지 로드
        segmentation = load_img(segmentation_file, target_size=target_size, color_mode="grayscale")
        segmentation = img_to_array(segmentation)
        segmentation = segmentation / 255.0  # 픽셀 값을 0과 1 사이로 정규화

        images.append(image)
        labels.append(segmentation)

    # numpy array로 변환
    images = np.array(images)
    labels = np.array(labels)

    return images, labels

# 학습 데이터 로드
x_train, y_train = load_data(image_train_files, segmentation_train_files, target_size)

# 학습 데이터를 평가하는 데이터 분할
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# 테스트 데이터 로드
x_test, y_test = load_data(image_test_files, segmentation_test_files, target_size)

# %%
# 첫 번째 테스트 이미지를 가져옵니다.
test_image = y_test[2]

# 이미지를 시각화합니다.
plt.imshow(test_image)
plt.show()

# %%
print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# x_train shape: (64, 480, 272, 3)
# y_train shape: (64, 480, 272, 1)

# %%
# 모델 생성
input_shape = (480, 272, 3)  # 실제 이미지의 크기
model = create_model(input_shape=input_shape)  # 실제 이미지 크기에 맞게 모델 생성

# 모델 컴파일
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# 모델 학습
history = model.fit(x_train, y_train, batch_size=8, epochs=40, validation_data=(x_val, y_val))

# 모델 저장
model.save('unet_model.h5')
# Out:
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# Epoch 1/40
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 8/8 [==============================] - 194s 24s/step - loss: 0.4033 - accuracy: 0.9091 - val_loss: 0.6951 - val_accuracy: 0.9890
# Epoch 2/40
# 8/8 [==============================] - 197s 25s/step - loss: 0.1788 - accuracy: 0.9911 - val_loss: 3.8500 - val_accuracy: 0.9888
# Epoch 3/40
# 8/8 [==============================] - 196s 25s/step - loss: 0.1151 - accuracy: 0.9929 - val_loss: 22.5258 - val_accuracy: 0.9915
# Epoch 4/40
# 8/8 [==============================] - 198s 25s/step - loss: 0.0634 - accuracy: 0.9932 - val_loss: 2.7455 - val_accuracy: 0.9925
# Epoch 5/40
# 8/8 [==============================] - 199s 25s/step - loss: 0.0397 - accuracy: 0.9933 - val_loss: 16.8314 - val_accuracy: 0.9925
# Epoch 6/40
# 8/8 [==============================] - 198s 25s/step - loss: 0.0287 - accuracy: 0.9933 - val_loss: 2.4960 - val_accuracy: 0.9925
# Epoch 7/40
# 8/8 [==============================] - 198s 25s/step - loss: 0.0217 - accuracy: 0.9933 - val_loss: 0.2284 - val_accuracy: 0.9925
# Epoch 8/40
# 8/8 [==============================] - 200s 25s/step - loss: 0.0194 - accuracy: 0.9933 - val_loss: 0.6276 - val_accuracy: 0.9925
# Epoch 9/40
# 8/8 [==============================] - 199s 25s/step - loss: 0.0205 - accuracy: 0.9933 - val_loss: 0.4080 - val_accuracy: 0.9925
# Epoch 10/40
# 8/8 [==============================] - 199s 25s/step - loss: 0.0171 - accuracy: 0.9933 - val_loss: 0.2975 - val_accuracy: 0.9925
# Epoch 11/40
# 8/8 [==============================] - 197s 25s/step - loss: 0.0162 - accuracy: 0.9933 - val_loss: 0.1469 - val_accuracy: 0.9925
# Epoch 12/40
# 8/8 [==============================] - 198s 25s/step - loss: 0.0154 - accuracy: 0.9933 - val_loss: 0.1596 - val_accuracy: 0.9925
# Epoch 13/40
# 8/8 [==============================] - 210s 27s/step - loss: 0.0142 - accuracy: 0.9933 - val_loss: 0.0514 - val_accuracy: 0.9925
# Epoch 14/40
# 8/8 [==============================] - 214s 27s/step - loss: 0.0140 - accuracy: 0.9933 - val_loss: 0.2732 - val_accuracy: 0.9925
# Epoch 15/40
# 8/8 [==============================] - 213s 27s/step - loss: 0.0158 - accuracy: 0.9933 - val_loss: 0.3608 - val_accuracy: 0.9925
# Epoch 16/40
# 8/8 [==============================] - 214s 27s/step - loss: 0.0146 - accuracy: 0.9933 - val_loss: 0.0420 - val_accuracy: 0.9925
# Epoch 17/40
# 8/8 [==============================] - 195s 25s/step - loss: 0.0134 - accuracy: 0.9933 - val_loss: 0.0360 - val_accuracy: 0.9925
# Epoch 18/40
# 8/8 [==============================] - 196s 25s/step - loss: 0.0125 - accuracy: 0.9933 - val_loss: 0.0532 - val_accuracy: 0.9925
# Epoch 19/40
# 8/8 [==============================] - 198s 25s/step - loss: 0.0138 - accuracy: 0.9933 - val_loss: 0.1260 - val_accuracy: 0.9925
# Epoch 20/40
# 8/8 [==============================] - 196s 25s/step - loss: 0.0126 - accuracy: 0.9933 - val_loss: 0.0669 - val_accuracy: 0.9925
# Epoch 21/40
# 8/8 [==============================] - 197s 25s/step - loss: 0.0116 - accuracy: 0.9933 - val_loss: 0.0157 - val_accuracy: 0.9925
# Epoch 22/40
# 8/8 [==============================] - 197s 25s/step - loss: 0.0114 - accuracy: 0.9933 - val_loss: 0.0288 - val_accuracy: 0.9925
# Epoch 23/40
# 8/8 [==============================] - 196s 24s/step - loss: 0.0115 - accuracy: 0.9933 - val_loss: 0.0208 - val_accuracy: 0.9925
# Epoch 24/40
# 8/8 [==============================] - 197s 25s/step - loss: 0.0106 - accuracy: 0.9933 - val_loss: 0.0316 - val_accuracy: 0.9925
# Epoch 25/40
# 8/8 [==============================] - 197s 25s/step - loss: 0.0104 - accuracy: 0.9933 - val_loss: 0.0395 - val_accuracy: 0.9925
# Epoch 26/40
# 8/8 [==============================] - 194s 24s/step - loss: 0.0106 - accuracy: 0.9933 - val_loss: 0.0354 - val_accuracy: 0.9925
# Epoch 27/40
# 8/8 [==============================] - 196s 25s/step - loss: 0.0107 - accuracy: 0.9933 - val_loss: 0.0144 - val_accuracy: 0.9925
# Epoch 28/40
# 8/8 [==============================] - 193s 24s/step - loss: 0.0100 - accuracy: 0.9933 - val_loss: 0.0269 - val_accuracy: 0.9925
# Epoch 29/40
# 8/8 [==============================] - 195s 25s/step - loss: 0.0098 - accuracy: 0.9933 - val_loss: 0.0265 - val_accuracy: 0.9925
# Epoch 30/40
# 8/8 [==============================] - 193s 24s/step - loss: 0.0099 - accuracy: 0.9933 - val_loss: 0.0260 - val_accuracy: 0.9925
# Epoch 31/40
# 8/8 [==============================] - 198s 25s/step - loss: 0.0099 - accuracy: 0.9933 - val_loss: 0.0202 - val_accuracy: 0.9925
# Epoch 32/40
# 8/8 [==============================] - 196s 25s/step - loss: 0.0095 - accuracy: 0.9933 - val_loss: 0.0247 - val_accuracy: 0.9925
# Epoch 33/40
# 8/8 [==============================] - 196s 25s/step - loss: 0.0091 - accuracy: 0.9933 - val_loss: 0.0227 - val_accuracy: 0.9925
# Epoch 34/40
# 8/8 [==============================] - 206s 26s/step - loss: 0.0088 - accuracy: 0.9933 - val_loss: 0.0249 - val_accuracy: 0.9925
# Epoch 35/40
# 8/8 [==============================] - 195s 25s/step - loss: 0.0086 - accuracy: 0.9933 - val_loss: 0.0501 - val_accuracy: 0.9925
# Epoch 36/40
# 8/8 [==============================] - 195s 25s/step - loss: 0.0085 - accuracy: 0.9933 - val_loss: 0.0171 - val_accuracy: 0.9925
# Epoch 37/40
# 8/8 [==============================] - 197s 25s/step - loss: 0.0089 - accuracy: 0.9933 - val_loss: 0.0294 - val_accuracy: 0.9925
# Epoch 38/40
# 8/8 [==============================] - 193s 24s/step - loss: 0.0087 - accuracy: 0.9933 - val_loss: 0.0122 - val_accuracy: 0.9925
# Epoch 39/40
# 8/8 [==============================] - 195s 24s/step - loss: 0.0084 - accuracy: 0.9933 - val_loss: 0.0149 - val_accuracy: 0.9925
# Epoch 40/40
# 8/8 [==============================] - 196s 25s/step - loss: 0.0084 - accuracy: 0.9933 - val_loss: 0.0289 - val_accuracy: 0.9925
# D:\Anaconda\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# 모델 평가
loss, acc = model.evaluate(x_test, y_test)
print(f"Test Loss: {loss}, Test Accuracy: {acc}")

# 모델 예측
predictions = model.predict(x_test)
# Out:
# 1/1 [==============================] - 10s 10s/step - loss: 0.0233 - accuracy: 0.9935
# Test Loss: 0.02326735481619835, Test Accuracy: 0.9935286641120911
# 1/1 [==============================] - 10s 10s/step

# %%
test_image2 = y_test[2]

# 이미지를 시각화합니다.
plt.imshow(test_image2)
plt.show()

# %%
# 예측 결과 시각화
fig, ax = plt.subplots(1, 2)
ax[0].imshow(x_test[12] / 255.0)        # 원본 이미지
ax[0].set_title("Input Image")
ax[1].imshow(predictions[12].squeeze(), cmap='gray')  # 예측된 세그멘테이션 결과
ax[1].set_title("Predicted Segmentation")
plt.show()

# %%
# 결과를 확인하기 위해 작성한 코드
print(predictions[1])
# Out:
# [[[6.28437568e-03]
#   [7.82916031e-04]
#   [8.50682787e-04]
#   ...
#   [2.83555919e-03]
#   [2.15932098e-03]
#   [1.11754918e-02]]
#
#  [[5.63799462e-04]
#   [3.91863323e-05]
#   [5.25789692e-05]
#   ...
#   [1.81974057e-04]
#   [1.01279235e-04]
#   [2.02802010e-03]]
#
#  [[6.02791144e-04]
#   [5.51016237e-05]
#   [8.24116214e-05]
#   ...
#   [2.07529985e-04]
#   [9.58749661e-05]
#   [2.15037097e-03]]
#
#  ...
#
#  [[1.30833709e-03]
#   [1.49801112e-04]
#   [9.57412994e-05]
#   ...
#   [1.48723717e-04]
#   [1.18977179e-04]
#   [2.71499064e-03]]
#
#  [[1.48426520e-03]
#   [1.78658098e-04]
#   [1.51355649e-04]
#   ...
#   [1.70251369e-04]
#   [1.38194388e-04]
#   [3.06382752e-03]]
#
#  [[1.13075729e-02]
#   [3.73625942e-03]
#   [4.03652433e-03]
#   ...
#   [3.36124119e-03]
#   [2.95135402e-03]
#   [2.26648673e-02]]]

# %%
print(predictions[2].shape)
# Out:
# (480, 272, 1)
