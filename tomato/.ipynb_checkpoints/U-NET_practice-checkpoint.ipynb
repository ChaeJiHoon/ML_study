# %%
import tensorflow as tf
import cv2
import json
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Cropping2D, Dropout,BatchNormalization, Activation
from tensorflow.keras.models import Model
from skimage.transform import resize
from keras.layers import Conv2DTranspose
from tensorflow.keras.preprocessing.image import img_to_array, load_img

os.environ["CUDA_VISIBLE_DEVICES"]="0"    
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)

    except RuntimeError as e:
        print(e)
        
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        # 필요한 만큼만 메모리를 사용하도록 설정
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        # 프로그램 시작시에 접근 가능한 장치가 설정되어야만 합니다
        print(e)
else:
    # GPU가 없는 경우, CPU를 사용
    print('GPU not available, using CPU instead.')

# %%
#이미지 전처리
img_directory = 'E:\\Unet\\만개꽃_축소이미지'
json_directory = 'E:\\Unet\\만개꽃_축소JSON'

#400개의 이미지와 Json데이터 파일 로드
image_files = [os.path.join(img_directory, file) for file in os.listdir(img_directory) if file.endswith('.png')][:400]
json_files = [os.path.join(json_directory, file.replace('.png', '.json')) for file in os.listdir(img_directory) if file.endswith('.png')][:400]

#잘 로드 되었는지 확인하는 코드 
print(f"Number of image files: {len(image_files)}")
print(f"Number of json files: {len(json_files)}")

#JSON 파일에서 좌표 데이터를 로드
#좌표 데이터를 기반으로 세그멘테이션 마스크를 생성
#생성된 세그멘테이션 마스크를 이미지 파일로 저장
#세그멘테이션 마스크를 화면에 출력
for image_file, json_file in zip(image_files, json_files):
    image = Image.open(image_file)
    image = np.array(image)

    if image is None:    #파일이 없다면 출력
        print(f"Cannot load image: {image_file}")
        continue

    with open(json_file, 'r') as f:
        data = json.load(f)

    #Json데이터속 가로,세로 정보를 가져옴
    original_size = (data['imageWidth'], data['imageHeight'])

    # 세그멘테이션 이미지 초기화 (모든 픽셀 값이 0인 이미지)
    segmentation = np.zeros((original_size[1], original_size[0]), dtype=np.uint8)

    shapes = data['shapes']
    
    # points로 가져온 좌표 안쪽은 모두 1로 라벨링 하는 코드
    for shape in shapes:
        points = np.array(shape['points'], dtype=np.int32)
        cv2.fillPoly(segmentation, [points], 1)
    
    # 라벨링된 이미지 새로운 경로에 저장
    new_image_path = os.path.join("E:/Unet/만개꽃/", os.path.split(image_file)[1].replace('.png', '_seg.png'))

    
    img_pil = Image.fromarray(segmentation * 255)  # 0과 1로 이루어진 이미지를 0과 255로 변환
    img_pil.save(new_image_path)

    # 세그멘테이션 이미지를 화면에 출력
    plt.imshow(segmentation, cmap='gray')
    plt.show()
# Out:
# Number of image files: 400
# Number of json files: 400

# %%
#컨볼루션 블록
def ConvBlock(filters, inputs):
    # 첫 번째 컨볼루션 레이어
    # filters: 필터(뉴런)의 수, (3, 3): 커널의 크기, padding='same': 입력과 출력의 크기를 동일하게 유지
    x = Conv2D(filters, (3, 3), padding='same')(inputs)
    #Conv2D 함수는 케라스에서 2차원 입력에 대한 컨볼루션 연산을 수행하는 함수

    # 첫 번째 컨볼루션 레이어 후 배치 정규화
    # 이는 각 배치별로 입력을 정규화하여 네트워크가 더 빠르고 안정적으로 학습할 수 있도록 돕는다
    x = BatchNormalization()(x)

    # ReLU 활성화 함수 적용
    # ReLU는 음수를 0으로 만들어 비선형성을 도입하고, 학습 중 기울기 소실 문제를 완화하는 기능
    x = Activation('relu')(x)

    # 두 번째 컨볼루션 레이어
    # 동일한 수의 필터와 커널 크기, 패딩을 사용하여 또 다른 특징 맵을 생성
    x = Conv2D(filters, (3, 3), padding='same')(x)

    # 두 번째 컨볼루션 레이어 후 배치 정규화
    x = BatchNormalization()(x)

    # ReLU 활성화 함수 적용
    x = Activation('relu')(x)

    # 이 블록의 최종 출력을 반환
    return x

# %%
# 모델을 만드는 함수
# 이 함수는 입력 텐서의 형태를 매개변수로 받아들입니다.
def create_model(input_shape):
    inputs = Input(input_shape)

    #첫 번째 컨볼루션 블록 conv1은 64개의 필터를 사용
    #드롭아웃을 적용하여 과적합을 방지
    #맥스풀링으로 특징 맵의 크기를 축소 
    #인코더 시작 부분
    conv1 = ConvBlock(64, inputs)
    drop1 = Dropout(0.2)(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(drop1)

    #두 번째 컨볼루션 블록 conv2는 128개의 필터를 사용
    #위와 같이 드롭아웃과 맥스풀링을 수행
    conv2 = ConvBlock(128, pool1)
    drop2 = Dropout(0.2)(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(drop2)

    #세 번째 컨볼루션블록 conv3는 256개의 필터를 사용
    #드롭아웃을 적용합
    #여기서는 맥스풀링을 수행하지 않음
    #U-Net의 "Bridge" 부분으로 전환되기 전 단계
    conv3 = ConvBlock(256, pool2)
    drop3 = Dropout(0.2)(conv3)

    # Bridge
    bridge = ConvBlock(512, drop3)

    #Conv2DTranspose: 이 함수는 디코더를 수행하는 레이어
    #Conv2DTranspose는 입력 특징 맵의 차원을 확장하는 데 사용
    #특히 세그멘테이션과 같은 작업에서 출력 이미지의 해상도를 높이는 데 유용
    # Conv2DTranspose(필터수, 컨볼루션 크기(필터 크기), 스트라이드, 패딩 방식)(레이어의 입력으로 사용되는 특징 맵)
    # 디코더 시작, 업샘플링과 컨볼루션을 사용하여 특징 맵의 크기를 다시 늘림
    up4 = Conv2DTranspose(128, 2, strides=(2, 2), padding='same')(bridge)

    #concatenate: 이 함수는 주어진 여러 특징 맵을 합치는 데 사용
    #concatenate는 이전 층의 정보를 현재 층에 추가하여 네트워크가 더 잘 일반화하고 세부 정보를 잃지 않도록 도와준다.
    #특징 맵을 합칠 때는 다양한 특징 맵들의 채널을 서로 붙여서 더 깊은 특징 맵 제작
    #[drop2, up4]: 이 리스트는 합칠 두 개의 특징 맵
    #axis=3: 이는 특징 맵을 합칠 축을 지정
    merge4 = concatenate([drop2, up4], axis=3)
    conv4 = ConvBlock(128, merge4)
    drop4 = Dropout(0.2)(conv4)

    up5 = Conv2DTranspose(64, 2, strides=(2, 2), padding='same')(drop4)
    merge5 = concatenate([drop1, up5], axis=3)
    conv5 = ConvBlock(64, merge5)
    drop5 = Dropout(0.2)(conv5)

    
    # 최종 컨볼루션 레이어를 추가하여 2개의 채널을 가진 특징 맵을 생성
    conv6 = Conv2D(2, 3, activation='relu', padding='same', kernel_initializer='he_normal')(drop5)
    conv7 = Conv2D(1, 1, activation='sigmoid')(conv6)

    # 입력과 최종 출력을 사용하여 모델을 정의
    model = Model(inputs=inputs, outputs=conv7)

    return model

# %%
img_directory = 'E:\\Unet\\만개꽃_축소이미지'
segmentation_directory = 'E:/Unet/만개꽃/'

image_files = [os.path.join(img_directory, file) for file in os.listdir(img_directory) if file.endswith('.png')]
segmentation_files = [os.path.join(segmentation_directory, file.replace('.png', '_seg.png')) for file in os.listdir(img_directory) if file.endswith('.png')]

# 학습 데이터와 테스트 데이터로 나누는 부분
image_train_files = image_files[:360]
segmentation_train_files = segmentation_files[:360]
image_test_files = image_files[360:400]
segmentation_test_files = segmentation_files[360:400]

# 이미지와 세그멘테이션 레이블의 크기를 조정할 크기
target_size = (480, 272)

#이미지와 세그멘테이션 마스크 파일을 로드
#이미지와 마스크의 크기를 모델의 입력 크기에 맞게 조정
#모든 이미지 데이터를 모델의 훈련을 위한 배열로 변환
def load_data(image_files, segmentation_files, target_size):
    images = []
    labels = []

    for image_file, segmentation_file in zip(image_files, segmentation_files):
        # 이미지 로드
        image = load_img(image_file, target_size=target_size)
        image = img_to_array(image)

        # 세그멘테이션 이미지 로드
        #세그멘테이션 마스크를 그레이스케일 모드로 로드, 이는 마스크가 채널이 하나인 2D 이미지임을 의미
        segmentation = load_img(segmentation_file, target_size=target_size, color_mode="grayscale")
        segmentation = img_to_array(segmentation)
        segmentation = segmentation / 255.0  # 픽셀 값을 0과 1 사이로 정규화

        images.append(image)
        labels.append(segmentation)

    # numpy array로 변환
    images = np.array(images)
    labels = np.array(labels)

    return images, labels

# 학습 데이터 로드
x_train, y_train = load_data(image_train_files, segmentation_train_files, target_size)

# 학습 데이터를 평가하는 데이터 분할
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# 테스트 데이터 로드
x_test, y_test = load_data(image_test_files, segmentation_test_files, target_size)

# %%
# 첫 번째 테스트 이미지를 가져옵니다.
test_image = y_test[2]

# 이미지를 시각화합니다.
plt.imshow(test_image)
plt.show()

# %%
print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# x_train shape: (288, 480, 272, 3)
# y_train shape: (288, 480, 272, 1)

# %%
# GPU를 사용할수 있는지 확인하기 위한 코드,없어도 됩니다.
import tensorflow as tf
from tensorflow.python.client import device_lib
print(tf.__version__)
device_lib.list_local_devices()
# Out:
# 2.10.0
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 5839718201285417835
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 4710740787
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 15123096774730526027
#  physical_device_desc: "device: 0, name: GeForce GTX 1060, pci bus id: 0000:01:00.0, compute capability: 6.1"
#  xla_global_id: 416903419]

# %%
# 모델 생성
input_shape = (480, 272, 3)  # 실제 이미지의 크기
model = create_model(input_shape=input_shape)  # 실제 이미지 크기에 맞게 모델 생성

# 모델 컴파일
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# 모델 학습
history = model.fit(x_train, y_train, batch_size=4, epochs=80, validation_data=(x_val, y_val))

# 모델 저장
model.save('unet_model.h5')
# Out:
# Epoch 1/80
# 72/72 [==============================] - 56s 681ms/step - loss: 0.0513 - accuracy: 0.9930 - val_loss: 0.0506 - val_accuracy: 0.9930
# Epoch 2/80
# 72/72 [==============================] - 49s 677ms/step - loss: 0.0272 - accuracy: 0.9930 - val_loss: 0.0325 - val_accuracy: 0.9930
# Epoch 3/80
# 72/72 [==============================] - 49s 680ms/step - loss: 0.0204 - accuracy: 0.9930 - val_loss: 0.0470 - val_accuracy: 0.9930
# Epoch 4/80
# 72/72 [==============================] - 49s 680ms/step - loss: 0.0180 - accuracy: 0.9930 - val_loss: 0.0303 - val_accuracy: 0.9930
# Epoch 5/80
# 72/72 [==============================] - 49s 681ms/step - loss: 0.0164 - accuracy: 0.9930 - val_loss: 0.0188 - val_accuracy: 0.9930
# Epoch 6/80
# 72/72 [==============================] - 49s 682ms/step - loss: 0.0150 - accuracy: 0.9930 - val_loss: 0.0156 - val_accuracy: 0.9930
# Epoch 7/80
# ...

# %%
# 모델 평가
loss, acc = model.evaluate(x_test, y_test, batch_size=4)
print(f"Test Loss: {loss}, Test Accuracy: {acc}")

# 모델 예측
predictions = []
batch_size = 4  # 배치 크기를 조절가능
for i in range(0, len(x_test), batch_size):
    batch = x_test[i:i+batch_size]
    batch_predictions = model.predict(batch)
    predictions.extend(batch_predictions)
# Out:
# 10/10 [==============================] - 2s 195ms/step - loss: 0.0105 - accuracy: 0.9975
# Test Loss: 0.010503389872610569, Test Accuracy: 0.9975109100341797
# ...
# 1/1 [==============================] - 0s 25ms/step

# %%
test_image2 = y_test[2]

# 이미지를 시각화
plt.imshow(test_image2)
plt.show()

# %%
# 예측 결과 시각화
fig, ax = plt.subplots(1, 2)
ax[0].imshow(x_test[18] / 255.0)        # 원본 이미지
ax[0].set_title("Input Image")
ax[1].imshow(predictions[18].squeeze(), cmap='gray')  # 예측된 세그멘테이션 결과
ax[1].set_title("Predicted Segmentation")
plt.show()

# %%
# 결과를 확인하기 위해 작성한 코드
print(predictions[1])
# Out:
# [[[1.73418244e-04]
#   [1.54715934e-07]
#   [1.09981549e-07]
#   ...
#   [1.06521355e-07]
#   [2.44518134e-07]
#   [3.12757038e-05]]
#
#  [[9.64775040e-07]
#   [8.32342667e-11]
#   [1.31771177e-10]
#   ...
#   [1.18743723e-10]
#   [2.41363207e-10]
#   [3.18991454e-07]]
#
#  [[1.89811928e-07]
#   [8.33558014e-11]
#   [4.19924484e-10]
#   ...
#   [6.19312213e-10]
#   [1.08862597e-09]
#   [5.93231277e-07]]
#
#  ...
#
#  [[1.31301157e-08]
#   [6.59892800e-12]
#   [6.94102935e-12]
#   ...
#   [7.65787364e-11]
#   [3.23701232e-10]
#   [6.06405251e-07]]
#
#  [[6.05611774e-08]
#   [1.10438811e-10]
#   [2.47367071e-10]
#   ...
#   [1.25393318e-09]
#   [1.75200299e-09]
#   [1.27965086e-06]]
#
#  [[1.75592995e-05]
#   [3.38254949e-07]
#   [5.04934519e-07]
#   ...
#   [2.16102819e-07]
#   [4.22369311e-07]
#   [6.62157981e-05]]]

# %%
# 모델 저장, 다른이름으로 저장
model.save('unet_model_Flower.h5')
