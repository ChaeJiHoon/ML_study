# %%
import tensorflow as tf
import cv2
import json
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Cropping2D, Dropout,BatchNormalization, Activation
from tensorflow.keras.models import Model
from skimage.transform import resize
from keras.layers import Conv2DTranspose
from tensorflow.keras.preprocessing.image import img_to_array, load_img

os.environ["CUDA_VISIBLE_DEVICES"]="-0"    
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)

    except RuntimeError as e:
        print(e)
        
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        # 필요한 만큼만 메모리를 사용하도록 설정
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        # 프로그램 시작시에 접근 가능한 장치가 설정되어야만 합니다
        print(e)
else:
    # GPU가 없는 경우, CPU를 사용
    print('GPU not available, using CPU instead.')

# %%
img_directory = 'E:\\Unet\\만개꽃_축소이미지'
json_directory = 'E:\\Unet\\만개꽃_축소JSON'

image_files = [os.path.join(img_directory, file) for file in os.listdir(img_directory) if file.endswith('.png')][:120]
json_files = [os.path.join(json_directory, file.replace('.png', '.json')) for file in os.listdir(img_directory) if file.endswith('.png')][:120]

print(f"Number of image files: {len(image_files)}")
print(f"Number of json files: {len(json_files)}")

for image_file, json_file in zip(image_files, json_files):
    image = Image.open(image_file)
    image = np.array(image)

    if image is None:
        print(f"Cannot load image: {image_file}")
        continue

    with open(json_file, 'r') as f:
        data = json.load(f)

    original_size = (data['imageWidth'], data['imageHeight'])

    # 세그멘테이션 이미지 초기화 (모든 픽셀 값이 0인 이미지)
    segmentation = np.zeros((original_size[1], original_size[0]), dtype=np.uint8)

    shapes = data['shapes']
    
    # points로 가져온 좌표 안쪽은 모두 1로 라벨링 하는 코드
    for shape in shapes:
        points = np.array(shape['points'], dtype=np.int32)
        cv2.fillPoly(segmentation, [points], 1)
    
    # 
    new_image_path = os.path.join("E:/Unet/만개꽃/", os.path.split(image_file)[1].replace('.png', '_seg.png'))

    img_pil = Image.fromarray(segmentation * 255)  # 0과 1로 이루어진 이미지를 0과 255로 변환
    img_pil.save(new_image_path)

    # 세그멘테이션 이미지를 화면에 출력
    plt.imshow(segmentation, cmap='gray')
    plt.show()
# Out:
# Number of image files: 160
# Number of json files: 160

# %%
def ConvBlock(filters, inputs):
    x = Conv2D(filters, (3, 3), padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(filters, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

# %%
def create_model(input_shape):
    inputs = Input(input_shape)

    conv1 = ConvBlock(64, inputs)
    drop1 = Dropout(0.2)(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(drop1)

    conv2 = ConvBlock(128, pool1)
    drop2 = Dropout(0.2)(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(drop2)

    conv3 = ConvBlock(256, pool2)
    drop3 = Dropout(0.2)(conv3)

    # Bridge
    bridge = ConvBlock(512, drop3)

    up4 = Conv2DTranspose(128, 2, strides=(2, 2), padding='same')(bridge)
    merge4 = concatenate([drop2, up4], axis=3)
    conv4 = ConvBlock(128, merge4)
    drop4 = Dropout(0.2)(conv4)

    up5 = Conv2DTranspose(64, 2, strides=(2, 2), padding='same')(drop4)
    merge5 = concatenate([drop1, up5], axis=3)
    conv5 = ConvBlock(64, merge5)
    drop5 = Dropout(0.2)(conv5)

    conv6 = Conv2D(2, 3, activation='relu', padding='same', kernel_initializer='he_normal')(drop5)
    conv7 = Conv2D(1, 1, activation='sigmoid')(conv6)

    model = Model(inputs=inputs, outputs=conv7)

    return model

# %%
img_directory = 'E:\\Unet\\만개꽃_축소이미지'
segmentation_directory = 'E:/Unet/만개꽃/'

image_files = [os.path.join(img_directory, file) for file in os.listdir(img_directory) if file.endswith('.png')]
segmentation_files = [os.path.join(segmentation_directory, file.replace('.png', '_seg.png')) for file in os.listdir(img_directory) if file.endswith('.png')]

# 학습 데이터와 테스트 데이터로 나누는 부분
image_train_files = image_files[:120]
segmentation_train_files = segmentation_files[:120]
image_test_files = image_files[120:120]
segmentation_test_files = segmentation_files[120:120]

# 이미지와 세그멘테이션 레이블의 크기를 조정할 크기
target_size = (480, 272)

def load_data(image_files, segmentation_files, target_size):
    images = []
    labels = []

    for image_file, segmentation_file in zip(image_files, segmentation_files):
        # 이미지 로드
        image = load_img(image_file, target_size=target_size)
        image = img_to_array(image)

        # 세그멘테이션 이미지 로드
        segmentation = load_img(segmentation_file, target_size=target_size, color_mode="grayscale")
        segmentation = img_to_array(segmentation)
        segmentation = segmentation / 255.0  # 픽셀 값을 0과 1 사이로 정규화

        images.append(image)
        labels.append(segmentation)

    # numpy array로 변환
    images = np.array(images)
    labels = np.array(labels)

    return images, labels

# 학습 데이터 로드
x_train, y_train = load_data(image_train_files, segmentation_train_files, target_size)

# 학습 데이터를 평가하는 데이터 분할
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# 테스트 데이터 로드
x_test, y_test = load_data(image_test_files, segmentation_test_files, target_size)

# %%
# 첫 번째 테스트 이미지를 가져옵니다.
test_image = y_test[2]

# 이미지를 시각화합니다.
plt.imshow(test_image)
plt.show()

# %%
print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# x_train shape: (128, 480, 272, 3)
# y_train shape: (128, 480, 272, 1)

# %%
import tensorflow as tf
from tensorflow.python.client import device_lib
print(tf.__version__)
device_lib.list_local_devices()
# Out:
# 2.10.0
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 7508178544423884701
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 4710740787
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 15349571894092302633
#  physical_device_desc: "device: 0, name: GeForce GTX 1060, pci bus id: 0000:01:00.0, compute capability: 6.1"
#  xla_global_id: 416903419]

# %%
# 모델 생성
input_shape = (480, 272, 3)  # 실제 이미지의 크기
model = create_model(input_shape=input_shape)  # 실제 이미지 크기에 맞게 모델 생성

# 모델 컴파일
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# 모델 학습
history = model.fit(x_train, y_train, batch_size=4, epochs=50, validation_data=(x_val, y_val))

# 모델 저장
model.save('unet_model3.h5')
# Out:
# Epoch 1/50
# 32/32 [==============================] - 29s 679ms/step - loss: 0.1074 - accuracy: 0.9784 - val_loss: 0.6831 - val_accuracy: 0.9917
# Epoch 2/50
# 32/32 [==============================] - 21s 669ms/step - loss: 0.0374 - accuracy: 0.9918 - val_loss: 0.6702 - val_accuracy: 0.9917
# Epoch 3/50
# 32/32 [==============================] - 21s 670ms/step - loss: 0.0328 - accuracy: 0.9918 - val_loss: 0.0887 - val_accuracy: 0.9916
# Epoch 4/50
# 32/32 [==============================] - 21s 670ms/step - loss: 0.0252 - accuracy: 0.9918 - val_loss: 0.2136 - val_accuracy: 0.9917
# Epoch 5/50
# 32/32 [==============================] - 21s 670ms/step - loss: 0.0219 - accuracy: 0.9918 - val_loss: 0.0460 - val_accuracy: 0.9917
# Epoch 6/50
# 32/32 [==============================] - 21s 672ms/step - loss: 0.0198 - accuracy: 0.9918 - val_loss: 0.0515 - val_accuracy: 0.9917
# Epoch 7/50
# 32/32 [==============================] - 21s 670ms/step - loss: 0.0188 - accuracy: 0.9918 - val_loss: 0.0673 - val_accuracy: 0.9917
# Epoch 8/50
# 32/32 [==============================] - 21s 671ms/step - loss: 0.0189 - accuracy: 0.9918 - val_loss: 0.0522 - val_accuracy: 0.9917
# Epoch 9/50
# 32/32 [==============================] - 21s 671ms/step - loss: 0.0180 - accuracy: 0.9918 - val_loss: 0.0398 - val_accuracy: 0.9917
# Epoch 10/50
# 32/32 [==============================] - 21s 671ms/step - loss: 0.0175 - accuracy: 0.9918 - val_loss: 0.0508 - val_accuracy: 0.9917
# Epoch 11/50
# 32/32 [==============================] - 21s 671ms/step - loss: 0.0164 - accuracy: 0.9918 - val_loss: 0.0674 - val_accuracy: 0.9917
# Epoch 12/50
# 32/32 [==============================] - 21s 671ms/step - loss: 0.0175 - accuracy: 0.9918 - val_loss: 0.0219 - val_accuracy: 0.9917
# Epoch 13/50
# 32/32 [==============================] - 21s 671ms/step - loss: 0.0154 - accuracy: 0.9918 - val_loss: 0.0209 - val_accuracy: 0.9917
# Epoch 14/50
# 32/32 [==============================] - 21s 671ms/step - loss: 0.0151 - accuracy: 0.9924 - val_loss: 0.0377 - val_accuracy: 0.9917
# Epoch 15/50
# 32/32 [==============================] - 21s 671ms/step - loss: 0.0136 - accuracy: 0.9951 - val_loss: 0.0540 - val_accuracy: 0.9917
# Epoch 16/50
# 32/32 [==============================] - 21s 672ms/step - loss: 0.0118 - accuracy: 0.9958 - val_loss: 0.0586 - val_accuracy: 0.9917
# Epoch 17/50
# 32/32 [==============================] - 21s 672ms/step - loss: 0.0122 - accuracy: 0.9958 - val_loss: 0.0288 - val_accuracy: 0.9920
# Epoch 18/50
# 32/32 [==============================] - 21s 672ms/step - loss: 0.0114 - accuracy: 0.9957 - val_loss: 0.0298 - val_accuracy: 0.9937
# Epoch 19/50
# 32/32 [==============================] - 21s 673ms/step - loss: 0.0104 - accuracy: 0.9962 - val_loss: 0.0144 - val_accuracy: 0.9952
# Epoch 20/50
# 32/32 [==============================] - 21s 673ms/step - loss: 0.0111 - accuracy: 0.9960 - val_loss: 0.0700 - val_accuracy: 0.9917
# Epoch 21/50
# 32/32 [==============================] - 21s 672ms/step - loss: 0.0100 - accuracy: 0.9965 - val_loss: 0.0625 - val_accuracy: 0.9917
# Epoch 22/50
# 32/32 [==============================] - 21s 672ms/step - loss: 0.0114 - accuracy: 0.9958 - val_loss: 0.0433 - val_accuracy: 0.9918
# Epoch 23/50
# 32/32 [==============================] - 21s 672ms/step - loss: 0.0116 - accuracy: 0.9959 - val_loss: 0.0705 - val_accuracy: 0.9917
# Epoch 24/50
# 32/32 [==============================] - 21s 672ms/step - loss: 0.0110 - accuracy: 0.9959 - val_loss: 0.0181 - val_accuracy: 0.9952
# Epoch 25/50
# 32/32 [==============================] - 21s 673ms/step - loss: 0.0091 - accuracy: 0.9966 - val_loss: 0.0321 - val_accuracy: 0.9947
# Epoch 26/50
# 32/32 [==============================] - 21s 673ms/step - loss: 0.0094 - accuracy: 0.9966 - val_loss: 0.0317 - val_accuracy: 0.9923
# Epoch 27/50
# 32/32 [==============================] - 21s 672ms/step - loss: 0.0094 - accuracy: 0.9965 - val_loss: 0.0174 - val_accuracy: 0.9953
# Epoch 28/50
# 32/32 [==============================] - 21s 673ms/step - loss: 0.0086 - accuracy: 0.9968 - val_loss: 0.0431 - val_accuracy: 0.9922
# Epoch 29/50
# 32/32 [==============================] - 21s 672ms/step - loss: 0.0080 - accuracy: 0.9971 - val_loss: 0.0301 - val_accuracy: 0.9934
# Epoch 30/50
# 32/32 [==============================] - 21s 672ms/step - loss: 0.0081 - accuracy: 0.9970 - val_loss: 0.0346 - val_accuracy: 0.9928
# Epoch 31/50
# 32/32 [==============================] - 21s 671ms/step - loss: 0.0092 - accuracy: 0.9966 - val_loss: 0.0152 - val_accuracy: 0.9946
# Epoch 32/50
# 32/32 [==============================] - 21s 672ms/step - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.0229 - val_accuracy: 0.9948
# Epoch 33/50
# 32/32 [==============================] - 21s 673ms/step - loss: 0.0079 - accuracy: 0.9971 - val_loss: 0.0456 - val_accuracy: 0.9918
# Epoch 34/50
# 32/32 [==============================] - 21s 672ms/step - loss: 0.0071 - accuracy: 0.9973 - val_loss: 0.0335 - val_accuracy: 0.9932
# Epoch 35/50
# 32/32 [==============================] - 21s 673ms/step - loss: 0.0071 - accuracy: 0.9973 - val_loss: 0.0545 - val_accuracy: 0.9921
# Epoch 36/50
# 32/32 [==============================] - 21s 673ms/step - loss: 0.0074 - accuracy: 0.9973 - val_loss: 0.0313 - val_accuracy: 0.9946
# Epoch 37/50
# 32/32 [==============================] - 22s 673ms/step - loss: 0.0071 - accuracy: 0.9974 - val_loss: 0.0581 - val_accuracy: 0.9917
# Epoch 38/50
# 32/32 [==============================] - 21s 672ms/step - loss: 0.0064 - accuracy: 0.9976 - val_loss: 0.0611 - val_accuracy: 0.9918
# Epoch 39/50
# 32/32 [==============================] - 22s 674ms/step - loss: 0.0064 - accuracy: 0.9976 - val_loss: 0.0484 - val_accuracy: 0.9920
# Epoch 40/50
# 32/32 [==============================] - 21s 673ms/step - loss: 0.0071 - accuracy: 0.9973 - val_loss: 0.0545 - val_accuracy: 0.9919
# Epoch 41/50
# 32/32 [==============================] - 21s 673ms/step - loss: 0.0069 - accuracy: 0.9974 - val_loss: 0.0514 - val_accuracy: 0.9922
# Epoch 42/50
# 32/32 [==============================] - 21s 673ms/step - loss: 0.0065 - accuracy: 0.9975 - val_loss: 0.0759 - val_accuracy: 0.9917
# Epoch 43/50
# 32/32 [==============================] - 21s 672ms/step - loss: 0.0090 - accuracy: 0.9968 - val_loss: 0.0137 - val_accuracy: 0.9957
# Epoch 44/50
# 32/32 [==============================] - 21s 672ms/step - loss: 0.0085 - accuracy: 0.9969 - val_loss: 0.0523 - val_accuracy: 0.9928
# Epoch 45/50
# 32/32 [==============================] - 21s 673ms/step - loss: 0.0066 - accuracy: 0.9975 - val_loss: 0.0591 - val_accuracy: 0.9918
# Epoch 46/50
# 32/32 [==============================] - 22s 674ms/step - loss: 0.0072 - accuracy: 0.9973 - val_loss: 0.0335 - val_accuracy: 0.9935
# Epoch 47/50
# 32/32 [==============================] - 21s 673ms/step - loss: 0.0060 - accuracy: 0.9977 - val_loss: 0.0468 - val_accuracy: 0.9927
# Epoch 48/50
# 32/32 [==============================] - 21s 673ms/step - loss: 0.0062 - accuracy: 0.9977 - val_loss: 0.0496 - val_accuracy: 0.9921
# Epoch 49/50
# 32/32 [==============================] - 22s 674ms/step - loss: 0.0071 - accuracy: 0.9974 - val_loss: 0.0509 - val_accuracy: 0.9922
# Epoch 50/50
# 32/32 [==============================] - 21s 673ms/step - loss: 0.0065 - accuracy: 0.9976 - val_loss: 0.0472 - val_accuracy: 0.9925

# %%
# 모델 평가
loss, acc = model.evaluate(x_test, y_test, batch_size=4)
print(f"Test Loss: {loss}, Test Accuracy: {acc}")

# 모델 예측
predictions = []
batch_size = 4  # 배치 크기를 조절하실 수 있습니다.
for i in range(0, len(x_test), batch_size):
    batch = x_test[i:i+batch_size]
    batch_predictions = model.predict(batch)
    predictions.extend(batch_predictions)
# Out:
# 5/5 [==============================] - 1s 193ms/step - loss: 0.0489 - accuracy: 0.9935
# Test Loss: 0.04889548569917679, Test Accuracy: 0.9934642910957336
# 1/1 [==============================] - 0s 262ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step

# %%
test_image2 = y_test[2]

# 이미지를 시각화합니다.
plt.imshow(test_image2)
plt.show()

# %%
# 예측 결과 시각화
fig, ax = plt.subplots(1, 2)
ax[0].imshow(x_test[6] / 255.0)        # 원본 이미지
ax[0].set_title("Input Image")
ax[1].imshow(predictions[6].squeeze(), cmap='gray')  # 예측된 세그멘테이션 결과
ax[1].set_title("Predicted Segmentation")
plt.show()

# %%
# 결과를 확인하기 위해 작성한 코드
print(predictions[1])
# Out:
# [[[1.5104710e-03]
#   [5.1571147e-05]
#   [1.9355522e-05]
#   ...
#   [3.0735770e-05]
#   [8.1690290e-05]
#   [1.9430454e-03]]
#
#  [[6.0544840e-05]
#   [2.7359724e-07]
#   [4.0290537e-08]
#   ...
#   [5.4253672e-08]
#   [2.6055565e-07]
#   [4.4205291e-05]]
#
#  [[3.4120378e-05]
#   [2.6261095e-08]
#   [3.6330852e-09]
#   ...
#   [4.0999537e-09]
#   [2.6105031e-08]
#   [8.5586380e-06]]
#
#  ...
#
#  [[2.3153560e-05]
#   [2.7992786e-07]
#   [2.2582226e-07]
#   ...
#   [8.1302755e-07]
#   [1.9571335e-06]
#   [6.8058194e-05]]
#
#  [[3.5062618e-05]
#   [4.5576769e-07]
#   [4.0609214e-07]
#   ...
#   [1.7611071e-06]
#   [3.4330765e-06]
#   [9.2269758e-05]]
#
#  [[5.4431625e-04]
#   [3.2380056e-05]
#   [2.2790235e-05]
#   ...
#   [7.2043673e-05]
#   [1.4453496e-04]
#   [1.7493557e-03]]]

# %%
print(predictions[2].shape)
# Out:
# (480, 272, 1)
