# %%
# 필요한 라이브러리 임포트
import os
import json
from PIL import Image, ExifTags, ImageOps
import cv2
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from keras import regularizers
import matplotlib.pyplot as plt  # matplotlib 라이브러리 import
# Out:
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# 새로운 이미지 크기
new_size = (270, 480)

# %%
def preprocess_data(json_files, img_directory, new_size):  
    images = []  
    labels = []  

    for json_file in json_files:  
        with open(json_file, 'r') as f:  
            data = json.load(f)  

        img_file = data['imagePath']  
        img_path = os.path.join(img_directory, img_file)  

        img = Image.open(img_path)  
        img = ImageOps.exif_transpose(img)

        original_size = np.array(img).shape[:2]
        img = np.array(img)
        img = cv2.resize(img, new_size)  

        resize_ratio = (new_size[0] / original_size[1], new_size[1] / original_size[0])  # width, height
                
        for shape in data['shapes']:  
            if shape['label'] == 'tom_flower_poly':  
                points = np.array(shape['points'], np.float32)
                points[:, 0] *= resize_ratio[0]  # width
                points[:, 1] *= resize_ratio[1]  # height
                points = points.astype(np.int32)

                cv2.polylines(img, [points], True, (255, 255, 255), 2)  # 색 테두리 추가

        plt.imshow(img)  
        plt.title('Image with Polygons')  
        #plt.show() 이미지를 보고싶다면 주석을 제거 

        images.append(img)  
        labels.append(1 if len([shape for shape in data['shapes'] if shape['label'] == 'tom_flower_poly']) >= 3 else 0)  

    images = np.array(images)  
    labels = np.array(labels)  
    return images, labels

# %%
# 모델 생성 함수
def create_model():
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(new_size[1], new_size[0], 3)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    Dropout(0.5)
    model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    Dropout(0.5)
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    Dropout(0.5)
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
# 데이터 디렉토리
directory = 'E:/tomato_label/097.지능형_스마트팜_통합_데이터(토마토)/01.데이터/1.Training/라벨링데이터/f.만개꽃'  
json_files = [os.path.join(directory, file) for file in os.listdir(directory) if file.endswith('.json')]
json_files = json_files[:4000]

img_directory = 'E:/tomato_label/097.지능형_스마트팜_통합_데이터(토마토)/01.데이터/1.Training/원천데이터/f.만개꽃/'

# %% [markdown]
# # 데이터 디렉토리 리스트
# directories = ['E:/tomato_label/097.지능형_스마트팜_통합_데이터(토마토)/01.데이터/1.Training/라벨링데이터/f.만개꽃',
#                'E:/tomato_label/097.지능형_스마트팜_통합_데이터(토마토)/01.데이터/1.Training/라벨링데이터/d1.꽃(개화군)']
#
# # 각 디렉토리에서 JSON 파일 불러오기
# json_files = []
# for directory in directories:
#     json_files.extend([os.path.join(directory, file) for file in os.listdir(directory) if file.endswith('.json')])
#
# # 이미지 디렉토리 리스트
# img_directories = ['E:/tomato_label/097.지능형_스마트팜_통합_데이터(토마토)/01.데이터/1.Training/원천데이터/f.만개꽃',
#                    'E:/tomato_label/097.지능형_스마트팜_통합_데이터(토마토)/01.데이터/1.Training/원천데이터/d1.꽃(개화군)']
#
# # 각 디렉토리에서 이미지 파일 불러오기
# img_files = []
# for img_directory in img_directories:
#     img_files.extend([os.path.join(img_directory, file) for file in os.listdir(img_directory) if file.endswith('.jpg')])

# %%
# 데이터 전처리
images, labels = preprocess_data(json_files, img_directory, new_size)

# 데이터 분할
train_images, test_images, train_labels, test_labels = train_test_split(images, labels, test_size=0.4, random_state=42)

# %%
# 모델 생성
model = create_model()
# Out:
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# 모델 학습
model.fit(train_images, train_labels, epochs=3, batch_size=32, validation_data=(test_images, test_labels))

# 라벨별 데이터 개수 출력
unique, counts = np.unique(labels, return_counts=True)
label_counts = dict(zip(unique, counts))

for label, count in label_counts.items():
    print(f"Label {label}: {count}개")
# Out:
# Epoch 1/3
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 28/28 [==============================] - 40s 1s/step - loss: 2413.7234 - accuracy: 0.7268 - val_loss: 3.2201 - val_accuracy: 0.7925
# Epoch 2/3
# 28/28 [==============================] - 39s 1s/step - loss: 0.5722 - accuracy: 0.8707 - val_loss: 0.8564 - val_accuracy: 0.7636
# Epoch 3/3
# 28/28 [==============================] - 39s 1s/step - loss: 0.0558 - accuracy: 0.9887 - val_loss: 1.3359 - val_accuracy: 0.7942
# Label 0: 1205개
# Label 1: 265개

# %%
from keras.models import Model
import matplotlib.pyplot as plt

# 중간 레이어의 출력을 추출하기 위한 모델 생성
layer_outputs = [layer.output for layer in model.layers[:1]] 
activation_model = Model(inputs=model.input, outputs=layer_outputs)

# 테스트 이미지 선택
img_tensor = test_images[0.] 
# 이미지 데이터 타입 변경 및 정규화
img_tensor = img_tensor.astype('float32') / 255.0

# 이미지 차원 확장 (모델에 입력하기 위해 필요한 4차원 형태로 변경)
img_tensor = np.expand_dims(img_tensor, axis=0)

# 이미지에 대한 특성 맵 생성
activations = activation_model.predict(img_tensor)

# 첫 번째 레이어의 특성 맵 시각화
first_layer_activation = activations[0]
print(first_layer_activation.shape)

fig, axes = plt.subplots(8, 4, figsize=(16, 32))

for i in range(8):
    for j in range(4):
        ax = axes[i, j]
        ax.matshow(first_layer_activation[:, :, i * 4 + j], cmap='viridis')
        ax.axis('off')

plt.show()
# Out:
# 1/1 [==============================] - 0s 44ms/step
# (478, 268, 32)

# %%
# 테스트 데이터 전처리 함수

def preprocess_test_images(directory, new_size):
    images = []
    labels = []

    for root, dirs, files in os.walk(directory):
        for img_file in files:
            img_path = os.path.join(root, img_file)
            
            img = Image.open(img_path)

            # 원본 이미지의 세로 가로 비율 계산
            ratio = img.height / img.width

            # 원본 비율을 유지하면서 가로축을 기준으로 축소할 크기 계산
            resize_size = (new_size[0], int(new_size[0] * ratio))

            # 원본 이미지를 적절하게 축소
            img = img.resize(resize_size)

            # 축소된 이미지를 원하는 최종 크기로 잘라내기
            upper = (img.size[1] - new_size[1]) / 3
            lower = (img.size[1] + new_size[1]) / 3

            img = img.crop((0, upper, new_size[0], lower))

            img = img.rotate(270)

            img = np.array(img)

            images.append(img)

            if "blossomed_3" in root:
                labels.append(1)
            else:
                labels.append(0)
    
    return np.array(images, dtype=object), np.array(labels)

# %%
# 테스트 데이터 전처리
blossomed_3_directory = "E:\\tomato_data\\TOMATO_BLOOMING_IMAGE_ENV_20231124\\TOMATO_BLOOMING_IMAGE_ENV_20231124\\blossomed_3"
blossomed_2_directory = "E:\\tomato_data\\TOMATO_BLOOMING_IMAGE_ENV_20231124\\TOMATO_BLOOMING_IMAGE_ENV_20231124\\blossomed_2"
blossomed_1_directory = "E:\\tomato_data\\TOMATO_BLOOMING_IMAGE_ENV_20231124\\TOMATO_BLOOMING_IMAGE_ENV_20231124\\blossomed_1"

test_images_3, test_labels_3 = preprocess_test_images(blossomed_3_directory, new_size)
test_images_2, test_labels_2 = preprocess_test_images(blossomed_2_directory, new_size)
test_images_1, test_labels_1 = preprocess_test_images(blossomed_1_directory, new_size)

# %%
# 테스트 데이터가 전처리가 잘 됐는지 확인하는 코드
# 보고싶은 이미지 출력

plt.figure(figsize=(10, 10))

plt.subplot(1, 3, 1)
plt.title('Blossomed 3')
test_images_3_float32 = np.array(test_images_3, dtype=np.float32) / 255.0
plt.imshow(test_images_3_float32[70])

plt.subplot(1, 3, 2)
plt.title('Blossomed 2')
test_images_2_float32 = np.array(test_images_2, dtype=np.float32) / 255.0
plt.imshow(test_images_2_float32[0])

plt.subplot(1, 3, 3)
plt.title('Blossomed 1')
test_images_1_float32 = np.array(test_images_2, dtype=np.float32) / 255.0
plt.imshow(test_images_1_float32[0])

plt.show()

# %%
# 모델 예측
predictions_3 = model.predict(test_images_3_float32)
predictions_2 = model.predict(test_images_2_float32)
predictions_1 = model.predict(test_images_1_float32)
# Out:
# 16/16 [==============================] - 6s 195ms/step
# 23/23 [==============================] - 5s 219ms/step
# 23/23 [==============================] - 5s 210ms/step

# %%
# 예측 결과를 이진 값으로 변환
predictions_3_binary = (predictions_3 > 0.5).astype("int32")
predictions_2_binary = (predictions_2 > 0.5).astype("int32")
predictions_1_binary = (predictions_1 > 0.5).astype("int32")

# %%
# 예측 결과 출력
print("Predictions for 'blossomed_3' images:")
for i, prediction in enumerate(predictions_3_binary):
    print(f"Image {i+1}: {'Blossomed' if prediction == 1 else 'Not blossomed'}")
    
print("Predictions for 'blossomed_2' images:")
for i, prediction in enumerate(predictions_2_binary):
    print(f"Image {i+1}: {'Blossomed' if prediction == 1 else 'Not blossomed'}")

print("\nPredictions for 'blossomed_1' images:")
for i, prediction in enumerate(predictions_1_binary):
    print(f"Image {i+1}: {'Blossomed' if prediction == 1 else 'Not blossomed'}")
# Out:
# Predictions for 'blossomed_3' images:
# Image 1: Not blossomed
# Image 2: Not blossomed
# Image 3: Not blossomed
# Image 4: Not blossomed
# Image 5: Not blossomed
# Image 6: Not blossomed
# Image 7: Not blossomed
# Image 8: Not blossomed
# Image 9: Not blossomed
# Image 10: Not blossomed
# Image 11: Not blossomed
# Image 12: Not blossomed
# Image 13: Not blossomed
# Image 14: Not blossomed
# Image 15: Not blossomed
# Image 16: Not blossomed
# Image 17: Not blossomed
# Image 18: Not blossomed
# Image 19: Not blossomed
# Image 20: Not blossomed
# Image 21: Not blossomed
# Image 22: Not blossomed
# Image 23: Not blossomed
# Image 24: Not blossomed
# Image 25: Not blossomed
# Image 26: Not blossomed
# Image 27: Not blossomed
# Image 28: Not blossomed
# Image 29: Not blossomed
# Image 30: Not blossomed
# Image 31: Not blossomed
# Image 32: Not blossomed
# Image 33: Not blossomed
# Image 34: Not blossomed
# Image 35: Not blossomed
# Image 36: Not blossomed
# Image 37: Not blossomed
# Image 38: Not blossomed
# Image 39: Not blossomed
# Image 40: Not blossomed
# Image 41: Not blossomed
# Image 42: Not blossomed
# Image 43: Not blossomed
# Image 44: Not blossomed
# Image 45: Not blossomed
# Image 46: Not blossomed
# Image 47: Not blossomed
# Image 48: Not blossomed
# Image 49: Not blossomed
# Image 50: Not blossomed
# Image 51: Not blossomed
# Image 52: Not blossomed
# Image 53: Not blossomed
# Image 54: Not blossomed
# Image 55: Not blossomed
# Image 56: Not blossomed
# Image 57: Not blossomed
# Image 58: Not blossomed
# Image 59: Not blossomed
# Image 60: Not blossomed
# Image 61: Not blossomed
# Image 62: Not blossomed
# Image 63: Not blossomed
# Image 64: Not blossomed
# Image 65: Not blossomed
# Image 66: Not blossomed
# Image 67: Not blossomed
# Image 68: Not blossomed
# Image 69: Not blossomed
# Image 70: Not blossomed
# Image 71: Not blossomed
# Image 72: Not blossomed
# Image 73: Not blossomed
# Image 74: Not blossomed
# Image 75: Not blossomed
# Image 76: Not blossomed
# Image 77: Not blossomed
# Image 78: Not blossomed
# Image 79: Not blossomed
# Image 80: Not blossomed
# Image 81: Not blossomed
# Image 82: Not blossomed
# Image 83: Not blossomed
# Image 84: Not blossomed
# Image 85: Not blossomed
# Image 86: Not blossomed
# Image 87: Not blossomed
# Image 88: Not blossomed
# Image 89: Not blossomed
# Image 90: Not blossomed
# Image 91: Not blossomed
# Image 92: Not blossomed
# Image 93: Not blossomed
# Image 94: Not blossomed
# Image 95: Not blossomed
# Image 96: Not blossomed
# Image 97: Not blossomed
# Image 98: Not blossomed
# Image 99: Not blossomed
# Image 100: Not blossomed
# Image 101: Not blossomed
# Image 102: Not blossomed
# Image 103: Not blossomed
# Image 104: Not blossomed
# Image 105: Not blossomed
# Image 106: Not blossomed
# Image 107: Not blossomed
# Image 108: Not blossomed
# Image 109: Not blossomed
# Image 110: Not blossomed
# Image 111: Not blossomed
# Image 112: Not blossomed
# Image 113: Not blossomed
# Image 114: Not blossomed
# Image 115: Not blossomed
# Image 116: Not blossomed
# Image 117: Not blossomed
# Image 118: Not blossomed
# Image 119: Not blossomed
# Image 120: Not blossomed
# Image 121: Not blossomed
# Image 122: Not blossomed
# Image 123: Not blossomed
# Image 124: Not blossomed
# Image 125: Not blossomed
# Image 126: Not blossomed
# Image 127: Not blossomed
# Image 128: Not blossomed
# Image 129: Not blossomed
# Image 130: Not blossomed
# Image 131: Not blossomed
# Image 132: Not blossomed
# Image 133: Not blossomed
# Image 134: Not blossomed
# Image 135: Not blossomed
# Image 136: Not blossomed
# Image 137: Not blossomed
# Image 138: Not blossomed
# Image 139: Not blossomed
# Image 140: Not blossomed
# Image 141: Not blossomed
# Image 142: Not blossomed
# Image 143: Not blossomed
# Image 144: Not blossomed
# Image 145: Not blossomed
# Image 146: Not blossomed
# Image 147: Not blossomed
# Image 148: Not blossomed
# Image 149: Not blossomed
# Image 150: Not blossomed
# Image 151: Not blossomed
# Image 152: Not blossomed
# Image 153: Not blossomed
# Image 154: Not blossomed
# Image 155: Not blossomed
# Image 156: Not blossomed
# Image 157: Not blossomed
# Image 158: Not blossomed
# Image 159: Not blossomed
# Image 160: Not blossomed
# Image 161: Not blossomed
# Image 162: Not blossomed
# Image 163: Not blossomed
# Image 164: Not blossomed
# Image 165: Not blossomed
# Image 166: Not blossomed
# Image 167: Not blossomed
# Image 168: Not blossomed
# Image 169: Not blossomed
# Image 170: Not blossomed
# Image 171: Not blossomed
# Image 172: Not blossomed
# Image 173: Not blossomed
# Image 174: Not blossomed
# Image 175: Not blossomed
# Image 176: Not blossomed
# Image 177: Not blossomed
# Image 178: Not blossomed
# Image 179: Not blossomed
# Image 180: Not blossomed
# Image 181: Not blossomed
# Image 182: Not blossomed
# Image 183: Not blossomed
# Image 184: Not blossomed
# Image 185: Not blossomed
# Image 186: Not blossomed
# Image 187: Not blossomed
# Image 188: Not blossomed
# Image 189: Not blossomed
# Image 190: Not blossomed
# Image 191: Not blossomed
# Image 192: Not blossomed
# Image 193: Not blossomed
# Image 194: Not blossomed
# Image 195: Not blossomed
# Image 196: Not blossomed
# Image 197: Not blossomed
# Image 198: Not blossomed
# Image 199: Not blossomed
# Image 200: Not blossomed
# Image 201: Not blossomed
# Image 202: Not blossomed
# Image 203: Not blossomed
# Image 204: Not blossomed
# Image 205: Not blossomed
# Image 206: Not blossomed
# Image 207: Not blossomed
# Image 208: Not blossomed
# Image 209: Not blossomed
# Image 210: Not blossomed
# Image 211: Not blossomed
# Image 212: Not blossomed
# Image 213: Not blossomed
# Image 214: Not blossomed
# Image 215: Not blossomed
# Image 216: Not blossomed
# Image 217: Not blossomed
# Image 218: Not blossomed
# Image 219: Not blossomed
# Image 220: Not blossomed
# Image 221: Not blossomed
# Image 222: Not blossomed
# Image 223: Not blossomed
# Image 224: Not blossomed
# Image 225: Not blossomed
# Image 226: Not blossomed
# Image 227: Not blossomed
# Image 228: Not blossomed
# Image 229: Not blossomed
# Image 230: Not blossomed
# Image 231: Not blossomed
# Image 232: Not blossomed
# Image 233: Not blossomed
# Image 234: Not blossomed
# Image 235: Not blossomed
# Image 236: Not blossomed
# Image 237: Not blossomed
# Image 238: Not blossomed
# Image 239: Not blossomed
# Image 240: Not blossomed
# Image 241: Not blossomed
# Image 242: Not blossomed
# Image 243: Not blossomed
# Image 244: Not blossomed
# Image 245: Not blossomed
# Image 246: Not blossomed
# Image 247: Not blossomed
# Image 248: Not blossomed
# Image 249: Not blossomed
# Image 250: Not blossomed
# Image 251: Not blossomed
# Image 252: Not blossomed
# Image 253: Not blossomed
# Image 254: Not blossomed
# Image 255: Not blossomed
# Image 256: Not blossomed
# Image 257: Not blossomed
# Image 258: Not blossomed
# Image 259: Not blossomed
# Image 260: Not blossomed
# Image 261: Not blossomed
# Image 262: Not blossomed
# Image 263: Not blossomed
# Image 264: Not blossomed
# Image 265: Not blossomed
# Image 266: Not blossomed
# Image 267: Not blossomed
# Image 268: Not blossomed
# Image 269: Not blossomed
# Image 270: Not blossomed
# Image 271: Not blossomed
# Image 272: Not blossomed
# Image 273: Not blossomed
# Image 274: Not blossomed
# Image 275: Not blossomed
# Image 276: Not blossomed
# Image 277: Not blossomed
# Image 278: Not blossomed
# Image 279: Not blossomed
# Image 280: Not blossomed
# Image 281: Not blossomed
# Image 282: Not blossomed
# Image 283: Not blossomed
# Image 284: Not blossomed
# Image 285: Not blossomed
# Image 286: Not blossomed
# Image 287: Not blossomed
# Image 288: Not blossomed
# Image 289: Not blossomed
# Image 290: Not blossomed
# Image 291: Not blossomed
# Image 292: Not blossomed
# Image 293: Not blossomed
# Image 294: Not blossomed
# Image 295: Not blossomed
# Image 296: Not blossomed
# Image 297: Not blossomed
# Image 298: Not blossomed
# Image 299: Not blossomed
# Image 300: Not blossomed
# Image 301: Not blossomed
# Image 302: Not blossomed
# Image 303: Not blossomed
# Image 304: Not blossomed
# Image 305: Not blossomed
# Image 306: Not blossomed
# Image 307: Not blossomed
# Image 308: Not blossomed
# Image 309: Not blossomed
# Image 310: Not blossomed
# Image 311: Not blossomed
# Image 312: Not blossomed
# Image 313: Not blossomed
# Image 314: Not blossomed
# Image 315: Not blossomed
# Image 316: Not blossomed
# Image 317: Not blossomed
# Image 318: Not blossomed
# Image 319: Not blossomed
# Image 320: Not blossomed
# Image 321: Not blossomed
# Image 322: Not blossomed
# Image 323: Not blossomed
# Image 324: Not blossomed
# Image 325: Not blossomed
# Image 326: Not blossomed
# Image 327: Not blossomed
# Image 328: Not blossomed
# Image 329: Not blossomed
# Image 330: Not blossomed
# Image 331: Not blossomed
# Image 332: Not blossomed
# Image 333: Not blossomed
# Image 334: Not blossomed
# Image 335: Not blossomed
# Image 336: Not blossomed
# Image 337: Not blossomed
# Image 338: Not blossomed
# Image 339: Not blossomed
# Image 340: Not blossomed
# Image 341: Not blossomed
# Image 342: Not blossomed
# Image 343: Not blossomed
# Image 344: Not blossomed
# Image 345: Not blossomed
# Image 346: Not blossomed
# Image 347: Not blossomed
# Image 348: Not blossomed
# Image 349: Not blossomed
# Image 350: Not blossomed
# Image 351: Not blossomed
# Image 352: Not blossomed
# Image 353: Not blossomed
# Image 354: Not blossomed
# Image 355: Not blossomed
# Image 356: Not blossomed
# Image 357: Not blossomed
# Image 358: Not blossomed
# Image 359: Not blossomed
# Image 360: Not blossomed
# Image 361: Not blossomed
# Image 362: Not blossomed
# Image 363: Not blossomed
# Image 364: Not blossomed
# Image 365: Not blossomed
# Image 366: Not blossomed
# Image 367: Not blossomed
# Image 368: Not blossomed
# Image 369: Not blossomed
# Image 370: Not blossomed
# Image 371: Not blossomed
# Image 372: Not blossomed
# Image 373: Not blossomed
# Image 374: Not blossomed
# Image 375: Not blossomed
# Image 376: Not blossomed
# Image 377: Not blossomed
# Image 378: Not blossomed
# Image 379: Not blossomed
# Image 380: Not blossomed
# Image 381: Not blossomed
# Image 382: Not blossomed
# Image 383: Not blossomed
# Image 384: Not blossomed
# Image 385: Not blossomed
# Image 386: Not blossomed
# Image 387: Not blossomed
# Image 388: Not blossomed
# Image 389: Not blossomed
# Image 390: Not blossomed
# Image 391: Not blossomed
# Image 392: Not blossomed
# Image 393: Not blossomed
# Image 394: Not blossomed
# Image 395: Not blossomed
# Image 396: Not blossomed
# Image 397: Not blossomed
# Image 398: Not blossomed
# Image 399: Not blossomed
# Image 400: Not blossomed
# Image 401: Not blossomed
# Image 402: Not blossomed
# Image 403: Not blossomed
# Image 404: Not blossomed
# Image 405: Not blossomed
# Image 406: Not blossomed
# Image 407: Not blossomed
# Image 408: Not blossomed
# Image 409: Not blossomed
# Image 410: Not blossomed
# Image 411: Not blossomed
# Image 412: Not blossomed
# Image 413: Not blossomed
# Image 414: Not blossomed
# Image 415: Not blossomed
# Image 416: Not blossomed
# Image 417: Not blossomed
# Image 418: Not blossomed
# Image 419: Not blossomed
# Image 420: Not blossomed
# Image 421: Not blossomed
# Image 422: Not blossomed
# Image 423: Not blossomed
# Image 424: Not blossomed
# Image 425: Not blossomed
# Image 426: Not blossomed
# Image 427: Not blossomed
# Image 428: Not blossomed
# Image 429: Not blossomed
# Image 430: Not blossomed
# Image 431: Not blossomed
# Image 432: Not blossomed
# Image 433: Not blossomed
# Image 434: Not blossomed
# Image 435: Not blossomed
# Image 436: Not blossomed
# Image 437: Not blossomed
# Image 438: Not blossomed
# Image 439: Not blossomed
# Image 440: Not blossomed
# Image 441: Not blossomed
# Image 442: Not blossomed
# Image 443: Not blossomed
# Image 444: Not blossomed
# Image 445: Not blossomed
# Image 446: Not blossomed
# Image 447: Not blossomed
# Image 448: Not blossomed
# Image 449: Not blossomed
# Image 450: Not blossomed
# Image 451: Not blossomed
# Image 452: Not blossomed
# Image 453: Not blossomed
# Image 454: Not blossomed
# Image 455: Not blossomed
# Image 456: Not blossomed
# Image 457: Not blossomed
# Image 458: Not blossomed
# Image 459: Not blossomed
# Image 460: Not blossomed
# Image 461: Not blossomed
# Image 462: Not blossomed
# Image 463: Not blossomed
# Image 464: Not blossomed
# Image 465: Not blossomed
# Image 466: Not blossomed
# Image 467: Not blossomed
# Image 468: Not blossomed
# Image 469: Not blossomed
# Image 470: Not blossomed
# Image 471: Not blossomed
# Image 472: Not blossomed
# Image 473: Not blossomed
# Image 474: Not blossomed
# Image 475: Not blossomed
# Image 476: Not blossomed
# Image 477: Not blossomed
# Image 478: Not blossomed
# Image 479: Not blossomed
# Image 480: Not blossomed
# Image 481: Not blossomed
# Image 482: Not blossomed
# Image 483: Not blossomed
# Image 484: Not blossomed
# Image 485: Not blossomed
# Image 486: Not blossomed
# Image 487: Not blossomed
# Image 488: Not blossomed
# Image 489: Not blossomed
# Image 490: Not blossomed
# Image 491: Not blossomed
# Predictions for 'blossomed_2' images:
# Image 1: Not blossomed
# Image 2: Not blossomed
# Image 3: Not blossomed
# Image 4: Not blossomed
# Image 5: Not blossomed
# Image 6: Not blossomed
# Image 7: Not blossomed
# Image 8: Not blossomed
# Image 9: Not blossomed
# Image 10: Not blossomed
# Image 11: Not blossomed
# Image 12: Not blossomed
# Image 13: Not blossomed
# Image 14: Not blossomed
# Image 15: Not blossomed
# Image 16: Not blossomed
# Image 17: Not blossomed
# Image 18: Not blossomed
# Image 19: Not blossomed
# Image 20: Not blossomed
# Image 21: Not blossomed
# Image 22: Not blossomed
# Image 23: Not blossomed
# Image 24: Not blossomed
# Image 25: Not blossomed
# Image 26: Not blossomed
# Image 27: Not blossomed
# Image 28: Not blossomed
# Image 29: Not blossomed
# Image 30: Not blossomed
# Image 31: Not blossomed
# Image 32: Not blossomed
# Image 33: Not blossomed
# Image 34: Not blossomed
# Image 35: Not blossomed
# Image 36: Not blossomed
# Image 37: Not blossomed
# Image 38: Not blossomed
# Image 39: Not blossomed
# Image 40: Not blossomed
# Image 41: Not blossomed
# Image 42: Not blossomed
# Image 43: Not blossomed
# Image 44: Not blossomed
# Image 45: Not blossomed
# Image 46: Not blossomed
# Image 47: Not blossomed
# Image 48: Not blossomed
# Image 49: Not blossomed
# Image 50: Not blossomed
# Image 51: Not blossomed
# Image 52: Not blossomed
# Image 53: Not blossomed
# Image 54: Not blossomed
# Image 55: Not blossomed
# Image 56: Not blossomed
# Image 57: Not blossomed
# Image 58: Not blossomed
# Image 59: Not blossomed
# Image 60: Not blossomed
# Image 61: Not blossomed
# Image 62: Not blossomed
# Image 63: Not blossomed
# Image 64: Not blossomed
# Image 65: Not blossomed
# Image 66: Not blossomed
# Image 67: Not blossomed
# Image 68: Not blossomed
# Image 69: Not blossomed
# Image 70: Not blossomed
# Image 71: Not blossomed
# Image 72: Not blossomed
# Image 73: Not blossomed
# Image 74: Not blossomed
# Image 75: Not blossomed
# Image 76: Not blossomed
# Image 77: Not blossomed
# Image 78: Not blossomed
# Image 79: Not blossomed
# Image 80: Not blossomed
# Image 81: Not blossomed
# Image 82: Not blossomed
# Image 83: Not blossomed
# Image 84: Not blossomed
# Image 85: Not blossomed
# Image 86: Not blossomed
# Image 87: Not blossomed
# Image 88: Not blossomed
# Image 89: Not blossomed
# Image 90: Not blossomed
# Image 91: Not blossomed
# Image 92: Not blossomed
# Image 93: Not blossomed
# Image 94: Not blossomed
# Image 95: Not blossomed
# Image 96: Not blossomed
# Image 97: Not blossomed
# Image 98: Not blossomed
# Image 99: Not blossomed
# Image 100: Not blossomed
# Image 101: Not blossomed
# Image 102: Not blossomed
# Image 103: Not blossomed
# Image 104: Not blossomed
# Image 105: Not blossomed
# Image 106: Not blossomed
# Image 107: Not blossomed
# Image 108: Not blossomed
# Image 109: Not blossomed
# Image 110: Not blossomed
# Image 111: Not blossomed
# Image 112: Not blossomed
# Image 113: Not blossomed
# Image 114: Not blossomed
# Image 115: Not blossomed
# Image 116: Not blossomed
# Image 117: Not blossomed
# Image 118: Not blossomed
# Image 119: Not blossomed
# Image 120: Not blossomed
# Image 121: Not blossomed
# Image 122: Not blossomed
# Image 123: Not blossomed
# Image 124: Not blossomed
# Image 125: Not blossomed
# Image 126: Not blossomed
# Image 127: Not blossomed
# Image 128: Not blossomed
# Image 129: Not blossomed
# Image 130: Not blossomed
# Image 131: Not blossomed
# Image 132: Not blossomed
# Image 133: Not blossomed
# Image 134: Not blossomed
# Image 135: Not blossomed
# Image 136: Not blossomed
# Image 137: Not blossomed
# Image 138: Not blossomed
# Image 139: Not blossomed
# Image 140: Not blossomed
# Image 141: Not blossomed
# Image 142: Not blossomed
# Image 143: Not blossomed
# Image 144: Not blossomed
# Image 145: Not blossomed
# Image 146: Not blossomed
# Image 147: Not blossomed
# Image 148: Not blossomed
# Image 149: Not blossomed
# Image 150: Not blossomed
# Image 151: Not blossomed
# Image 152: Not blossomed
# Image 153: Not blossomed
# Image 154: Not blossomed
# Image 155: Not blossomed
# Image 156: Not blossomed
# Image 157: Not blossomed
# Image 158: Not blossomed
# Image 159: Not blossomed
# Image 160: Not blossomed
# Image 161: Not blossomed
# Image 162: Not blossomed
# Image 163: Not blossomed
# Image 164: Not blossomed
# Image 165: Not blossomed
# Image 166: Not blossomed
# Image 167: Not blossomed
# Image 168: Not blossomed
# Image 169: Not blossomed
# Image 170: Not blossomed
# Image 171: Not blossomed
# Image 172: Not blossomed
# Image 173: Not blossomed
# Image 174: Not blossomed
# Image 175: Not blossomed
# Image 176: Not blossomed
# Image 177: Not blossomed
# Image 178: Not blossomed
# Image 179: Not blossomed
# Image 180: Not blossomed
# Image 181: Not blossomed
# Image 182: Not blossomed
# Image 183: Not blossomed
# Image 184: Not blossomed
# Image 185: Not blossomed
# Image 186: Not blossomed
# Image 187: Not blossomed
# Image 188: Not blossomed
# Image 189: Not blossomed
# Image 190: Not blossomed
# Image 191: Not blossomed
# Image 192: Not blossomed
# Image 193: Not blossomed
# Image 194: Not blossomed
# Image 195: Not blossomed
# Image 196: Not blossomed
# Image 197: Not blossomed
# Image 198: Not blossomed
# Image 199: Not blossomed
# Image 200: Not blossomed
# Image 201: Not blossomed
# Image 202: Not blossomed
# Image 203: Not blossomed
# Image 204: Not blossomed
# Image 205: Not blossomed
# Image 206: Not blossomed
# Image 207: Not blossomed
# Image 208: Not blossomed
# Image 209: Not blossomed
# Image 210: Not blossomed
# Image 211: Not blossomed
# Image 212: Not blossomed
# Image 213: Not blossomed
# Image 214: Not blossomed
# Image 215: Not blossomed
# Image 216: Not blossomed
# Image 217: Not blossomed
# Image 218: Not blossomed
# Image 219: Not blossomed
# Image 220: Not blossomed
# Image 221: Not blossomed
# Image 222: Not blossomed
# Image 223: Not blossomed
# Image 224: Not blossomed
# Image 225: Not blossomed
# Image 226: Not blossomed
# Image 227: Not blossomed
# Image 228: Not blossomed
# Image 229: Not blossomed
# Image 230: Not blossomed
# Image 231: Not blossomed
# Image 232: Not blossomed
# Image 233: Not blossomed
# Image 234: Not blossomed
# Image 235: Not blossomed
# Image 236: Not blossomed
# Image 237: Not blossomed
# Image 238: Not blossomed
# Image 239: Not blossomed
# Image 240: Not blossomed
# Image 241: Not blossomed
# Image 242: Not blossomed
# Image 243: Not blossomed
# Image 244: Not blossomed
# Image 245: Not blossomed
# Image 246: Not blossomed
# Image 247: Not blossomed
# Image 248: Not blossomed
# Image 249: Not blossomed
# Image 250: Not blossomed
# Image 251: Not blossomed
# Image 252: Not blossomed
# Image 253: Not blossomed
# Image 254: Not blossomed
# Image 255: Not blossomed
# Image 256: Not blossomed
# Image 257: Not blossomed
# Image 258: Not blossomed
# Image 259: Not blossomed
# Image 260: Not blossomed
# Image 261: Not blossomed
# Image 262: Not blossomed
# Image 263: Not blossomed
# Image 264: Not blossomed
# Image 265: Not blossomed
# Image 266: Not blossomed
# Image 267: Not blossomed
# Image 268: Not blossomed
# Image 269: Not blossomed
# Image 270: Not blossomed
# Image 271: Not blossomed
# Image 272: Not blossomed
# Image 273: Not blossomed
# Image 274: Not blossomed
# Image 275: Not blossomed
# Image 276: Not blossomed
# Image 277: Not blossomed
# Image 278: Not blossomed
# Image 279: Not blossomed
# Image 280: Not blossomed
# Image 281: Not blossomed
# Image 282: Not blossomed
# Image 283: Not blossomed
# Image 284: Not blossomed
# Image 285: Not blossomed
# Image 286: Not blossomed
# Image 287: Not blossomed
# Image 288: Not blossomed
# Image 289: Not blossomed
# Image 290: Not blossomed
# Image 291: Not blossomed
# Image 292: Not blossomed
# Image 293: Not blossomed
# Image 294: Not blossomed
# Image 295: Not blossomed
# Image 296: Not blossomed
# Image 297: Not blossomed
# Image 298: Not blossomed
# Image 299: Not blossomed
# Image 300: Not blossomed
# Image 301: Not blossomed
# Image 302: Not blossomed
# Image 303: Not blossomed
# Image 304: Not blossomed
# Image 305: Not blossomed
# Image 306: Not blossomed
# Image 307: Not blossomed
# Image 308: Not blossomed
# Image 309: Not blossomed
# Image 310: Not blossomed
# Image 311: Not blossomed
# Image 312: Not blossomed
# Image 313: Not blossomed
# Image 314: Not blossomed
# Image 315: Not blossomed
# Image 316: Not blossomed
# Image 317: Not blossomed
# Image 318: Not blossomed
# Image 319: Not blossomed
# Image 320: Not blossomed
# Image 321: Not blossomed
# Image 322: Not blossomed
# Image 323: Not blossomed
# Image 324: Not blossomed
# Image 325: Not blossomed
# Image 326: Not blossomed
# Image 327: Not blossomed
# Image 328: Not blossomed
# Image 329: Not blossomed
# Image 330: Not blossomed
# Image 331: Not blossomed
# Image 332: Not blossomed
# Image 333: Not blossomed
# Image 334: Not blossomed
# Image 335: Not blossomed
# Image 336: Not blossomed
# Image 337: Not blossomed
# Image 338: Not blossomed
# Image 339: Not blossomed
# Image 340: Not blossomed
# Image 341: Not blossomed
# Image 342: Not blossomed
# Image 343: Not blossomed
# Image 344: Not blossomed
# Image 345: Not blossomed
# Image 346: Not blossomed
# Image 347: Not blossomed
# Image 348: Not blossomed
# Image 349: Not blossomed
# Image 350: Not blossomed
# Image 351: Not blossomed
# Image 352: Not blossomed
# Image 353: Not blossomed
# Image 354: Not blossomed
# Image 355: Not blossomed
# Image 356: Not blossomed
# Image 357: Not blossomed
# Image 358: Not blossomed
# Image 359: Not blossomed
# Image 360: Not blossomed
# Image 361: Not blossomed
# Image 362: Not blossomed
# Image 363: Not blossomed
# Image 364: Not blossomed
# Image 365: Not blossomed
# Image 366: Not blossomed
# Image 367: Not blossomed
# Image 368: Not blossomed
# Image 369: Not blossomed
# Image 370: Not blossomed
# Image 371: Not blossomed
# Image 372: Not blossomed
# Image 373: Not blossomed
# Image 374: Not blossomed
# Image 375: Not blossomed
# Image 376: Not blossomed
# Image 377: Not blossomed
# Image 378: Not blossomed
# Image 379: Not blossomed
# Image 380: Not blossomed
# Image 381: Not blossomed
# Image 382: Not blossomed
# Image 383: Not blossomed
# Image 384: Not blossomed
# Image 385: Not blossomed
# Image 386: Not blossomed
# Image 387: Not blossomed
# Image 388: Not blossomed
# Image 389: Not blossomed
# Image 390: Not blossomed
# Image 391: Not blossomed
# Image 392: Not blossomed
# Image 393: Not blossomed
# Image 394: Not blossomed
# Image 395: Not blossomed
# Image 396: Not blossomed
# Image 397: Not blossomed
# Image 398: Not blossomed
# Image 399: Not blossomed
# Image 400: Not blossomed
# Image 401: Not blossomed
# Image 402: Not blossomed
# Image 403: Not blossomed
# Image 404: Not blossomed
# Image 405: Not blossomed
# Image 406: Not blossomed
# Image 407: Not blossomed
# Image 408: Not blossomed
# Image 409: Not blossomed
# Image 410: Not blossomed
# Image 411: Not blossomed
# Image 412: Not blossomed
# Image 413: Not blossomed
# Image 414: Not blossomed
# Image 415: Not blossomed
# Image 416: Not blossomed
# Image 417: Not blossomed
# Image 418: Not blossomed
# Image 419: Not blossomed
# Image 420: Not blossomed
# Image 421: Not blossomed
# Image 422: Not blossomed
# Image 423: Not blossomed
# Image 424: Not blossomed
# Image 425: Not blossomed
# Image 426: Not blossomed
# Image 427: Not blossomed
# Image 428: Not blossomed
# Image 429: Not blossomed
# Image 430: Not blossomed
# Image 431: Not blossomed
# Image 432: Not blossomed
# Image 433: Not blossomed
# Image 434: Not blossomed
# Image 435: Not blossomed
# Image 436: Not blossomed
# Image 437: Not blossomed
# Image 438: Not blossomed
# Image 439: Not blossomed
# Image 440: Not blossomed
# Image 441: Not blossomed
# Image 442: Not blossomed
# Image 443: Not blossomed
# Image 444: Not blossomed
# Image 445: Not blossomed
# Image 446: Not blossomed
# Image 447: Not blossomed
# Image 448: Not blossomed
# Image 449: Not blossomed
# Image 450: Not blossomed
# Image 451: Not blossomed
# Image 452: Not blossomed
# Image 453: Not blossomed
# Image 454: Not blossomed
# Image 455: Not blossomed
# Image 456: Not blossomed
# Image 457: Not blossomed
# Image 458: Not blossomed
# Image 459: Not blossomed
# Image 460: Not blossomed
# Image 461: Not blossomed
# Image 462: Not blossomed
# Image 463: Not blossomed
# Image 464: Not blossomed
# Image 465: Not blossomed
# Image 466: Not blossomed
# Image 467: Not blossomed
# Image 468: Not blossomed
# Image 469: Not blossomed
# Image 470: Not blossomed
# Image 471: Not blossomed
# Image 472: Not blossomed
# Image 473: Not blossomed
# Image 474: Not blossomed
# Image 475: Not blossomed
# Image 476: Not blossomed
# Image 477: Not blossomed
# Image 478: Not blossomed
# Image 479: Not blossomed
# Image 480: Not blossomed
# Image 481: Not blossomed
# Image 482: Not blossomed
# Image 483: Not blossomed
# Image 484: Not blossomed
# Image 485: Not blossomed
# Image 486: Not blossomed
# Image 487: Not blossomed
# Image 488: Not blossomed
# Image 489: Not blossomed
# Image 490: Not blossomed
# Image 491: Not blossomed
# Image 492: Not blossomed
# Image 493: Not blossomed
# Image 494: Not blossomed
# Image 495: Not blossomed
# Image 496: Not blossomed
# Image 497: Not blossomed
# Image 498: Not blossomed
# Image 499: Not blossomed
# Image 500: Not blossomed
# Image 501: Not blossomed
# Image 502: Not blossomed
# Image 503: Not blossomed
# Image 504: Not blossomed
# Image 505: Not blossomed
# Image 506: Not blossomed
# Image 507: Not blossomed
# Image 508: Not blossomed
# Image 509: Not blossomed
# Image 510: Not blossomed
# Image 511: Not blossomed
# Image 512: Not blossomed
# Image 513: Not blossomed
# Image 514: Not blossomed
# Image 515: Not blossomed
# Image 516: Not blossomed
# Image 517: Not blossomed
# Image 518: Not blossomed
# Image 519: Not blossomed
# Image 520: Not blossomed
# Image 521: Not blossomed
# Image 522: Not blossomed
# Image 523: Not blossomed
# Image 524: Not blossomed
# Image 525: Not blossomed
# Image 526: Not blossomed
# Image 527: Not blossomed
# Image 528: Not blossomed
# Image 529: Not blossomed
# Image 530: Not blossomed
# Image 531: Not blossomed
# Image 532: Not blossomed
# Image 533: Not blossomed
# Image 534: Not blossomed
# Image 535: Not blossomed
# Image 536: Not blossomed
# Image 537: Not blossomed
# Image 538: Not blossomed
# Image 539: Not blossomed
# Image 540: Not blossomed
# Image 541: Not blossomed
# Image 542: Not blossomed
# Image 543: Not blossomed
# Image 544: Not blossomed
# Image 545: Not blossomed
# Image 546: Not blossomed
# Image 547: Not blossomed
# Image 548: Not blossomed
# Image 549: Not blossomed
# Image 550: Not blossomed
# Image 551: Not blossomed
# Image 552: Not blossomed
# Image 553: Not blossomed
# Image 554: Not blossomed
# Image 555: Not blossomed
# Image 556: Not blossomed
# Image 557: Not blossomed
# Image 558: Not blossomed
# Image 559: Not blossomed
# Image 560: Not blossomed
# Image 561: Not blossomed
# Image 562: Not blossomed
# Image 563: Not blossomed
# Image 564: Not blossomed
# Image 565: Not blossomed
# Image 566: Not blossomed
# Image 567: Not blossomed
# Image 568: Not blossomed
# Image 569: Not blossomed
# Image 570: Not blossomed
# Image 571: Not blossomed
# Image 572: Not blossomed
# Image 573: Not blossomed
# Image 574: Not blossomed
# Image 575: Not blossomed
# Image 576: Not blossomed
# Image 577: Not blossomed
# Image 578: Not blossomed
# Image 579: Not blossomed
# Image 580: Not blossomed
# Image 581: Not blossomed
# Image 582: Not blossomed
# Image 583: Not blossomed
# Image 584: Not blossomed
# Image 585: Not blossomed
# Image 586: Not blossomed
# Image 587: Not blossomed
# Image 588: Not blossomed
# Image 589: Not blossomed
# Image 590: Not blossomed
# Image 591: Not blossomed
# Image 592: Not blossomed
# Image 593: Not blossomed
# Image 594: Not blossomed
# Image 595: Not blossomed
# Image 596: Not blossomed
# Image 597: Not blossomed
# Image 598: Not blossomed
# Image 599: Not blossomed
# Image 600: Not blossomed
# Image 601: Not blossomed
# Image 602: Not blossomed
# Image 603: Not blossomed
# Image 604: Not blossomed
# Image 605: Not blossomed
# Image 606: Not blossomed
# Image 607: Not blossomed
# Image 608: Not blossomed
# Image 609: Not blossomed
# Image 610: Not blossomed
# Image 611: Not blossomed
# Image 612: Not blossomed
# Image 613: Not blossomed
# Image 614: Not blossomed
# Image 615: Not blossomed
# Image 616: Not blossomed
# Image 617: Not blossomed
# Image 618: Not blossomed
# Image 619: Not blossomed
# Image 620: Not blossomed
# Image 621: Not blossomed
# Image 622: Not blossomed
# Image 623: Not blossomed
# Image 624: Not blossomed
# Image 625: Not blossomed
# Image 626: Not blossomed
# Image 627: Not blossomed
# Image 628: Not blossomed
# Image 629: Not blossomed
# Image 630: Not blossomed
# Image 631: Not blossomed
# Image 632: Not blossomed
# Image 633: Not blossomed
# Image 634: Not blossomed
# Image 635: Not blossomed
# Image 636: Not blossomed
# Image 637: Not blossomed
# Image 638: Not blossomed
# Image 639: Not blossomed
# Image 640: Not blossomed
# Image 641: Not blossomed
# Image 642: Not blossomed
# Image 643: Not blossomed
# Image 644: Not blossomed
# Image 645: Not blossomed
# Image 646: Not blossomed
# Image 647: Not blossomed
# Image 648: Not blossomed
# Image 649: Not blossomed
# Image 650: Not blossomed
# Image 651: Not blossomed
# Image 652: Not blossomed
# Image 653: Not blossomed
# Image 654: Not blossomed
# Image 655: Not blossomed
# Image 656: Not blossomed
# Image 657: Not blossomed
# Image 658: Not blossomed
# Image 659: Not blossomed
# Image 660: Not blossomed
# Image 661: Not blossomed
# Image 662: Not blossomed
# Image 663: Not blossomed
# Image 664: Not blossomed
# Image 665: Not blossomed
# Image 666: Not blossomed
# Image 667: Not blossomed
# Image 668: Not blossomed
# Image 669: Not blossomed
# Image 670: Not blossomed
# Image 671: Not blossomed
# Image 672: Not blossomed
# Image 673: Not blossomed
# Image 674: Not blossomed
# Image 675: Not blossomed
# Image 676: Not blossomed
# Image 677: Not blossomed
# Image 678: Not blossomed
# Image 679: Not blossomed
# Image 680: Not blossomed
# Image 681: Not blossomed
# Image 682: Not blossomed
# Image 683: Not blossomed
# Image 684: Not blossomed
# Image 685: Not blossomed
# Image 686: Not blossomed
# Image 687: Not blossomed
# Image 688: Not blossomed
# Image 689: Not blossomed
# Image 690: Not blossomed
# Image 691: Not blossomed
# Image 692: Not blossomed
# Image 693: Not blossomed
# Image 694: Not blossomed
# Image 695: Not blossomed
# Image 696: Not blossomed
# Image 697: Not blossomed
# Image 698: Not blossomed
# Image 699: Not blossomed
# Image 700: Not blossomed
# Image 701: Not blossomed
# Image 702: Not blossomed
# Image 703: Not blossomed
# Image 704: Not blossomed
# Image 705: Not blossomed
# Image 706: Not blossomed
# Image 707: Not blossomed
# Image 708: Not blossomed
# Image 709: Not blossomed
# Image 710: Not blossomed
# Image 711: Not blossomed
# Image 712: Not blossomed
# Image 713: Not blossomed
# Image 714: Not blossomed
# Image 715: Not blossomed
# Image 716: Not blossomed
# Image 717: Not blossomed
# Image 718: Not blossomed
# Image 719: Not blossomed
# Image 720: Not blossomed
# Image 721: Not blossomed
# Image 722: Not blossomed
# Image 723: Not blossomed
# Image 724: Not blossomed
# Image 725: Not blossomed
# Image 726: Not blossomed
# Image 727: Not blossomed
# Image 728: Not blossomed
# Image 729: Not blossomed
# Image 730: Not blossomed
# Image 731: Not blossomed
# Image 732: Not blossomed
#
# Predictions for 'blossomed_1' images:
# Image 1: Not blossomed
# Image 2: Not blossomed
# Image 3: Not blossomed
# Image 4: Not blossomed
# Image 5: Not blossomed
# Image 6: Not blossomed
# Image 7: Not blossomed
# Image 8: Not blossomed
# Image 9: Not blossomed
# Image 10: Not blossomed
# Image 11: Not blossomed
# Image 12: Not blossomed
# Image 13: Not blossomed
# Image 14: Not blossomed
# Image 15: Not blossomed
# Image 16: Not blossomed
# Image 17: Not blossomed
# Image 18: Not blossomed
# Image 19: Not blossomed
# Image 20: Not blossomed
# Image 21: Not blossomed
# Image 22: Not blossomed
# Image 23: Not blossomed
# Image 24: Not blossomed
# Image 25: Not blossomed
# Image 26: Not blossomed
# Image 27: Not blossomed
# Image 28: Not blossomed
# Image 29: Not blossomed
# Image 30: Not blossomed
# Image 31: Not blossomed
# Image 32: Not blossomed
# Image 33: Not blossomed
# Image 34: Not blossomed
# Image 35: Not blossomed
# Image 36: Not blossomed
# Image 37: Not blossomed
# Image 38: Not blossomed
# Image 39: Not blossomed
# Image 40: Not blossomed
# Image 41: Not blossomed
# Image 42: Not blossomed
# Image 43: Not blossomed
# Image 44: Not blossomed
# Image 45: Not blossomed
# Image 46: Not blossomed
# Image 47: Not blossomed
# Image 48: Not blossomed
# Image 49: Not blossomed
# Image 50: Not blossomed
# Image 51: Not blossomed
# Image 52: Not blossomed
# Image 53: Not blossomed
# Image 54: Not blossomed
# Image 55: Not blossomed
# Image 56: Not blossomed
# Image 57: Not blossomed
# Image 58: Not blossomed
# Image 59: Not blossomed
# Image 60: Not blossomed
# Image 61: Not blossomed
# Image 62: Not blossomed
# Image 63: Not blossomed
# Image 64: Not blossomed
# Image 65: Not blossomed
# Image 66: Not blossomed
# Image 67: Not blossomed
# Image 68: Not blossomed
# Image 69: Not blossomed
# Image 70: Not blossomed
# Image 71: Not blossomed
# Image 72: Not blossomed
# Image 73: Not blossomed
# Image 74: Not blossomed
# Image 75: Not blossomed
# Image 76: Not blossomed
# Image 77: Not blossomed
# Image 78: Not blossomed
# Image 79: Not blossomed
# Image 80: Not blossomed
# Image 81: Not blossomed
# Image 82: Not blossomed
# Image 83: Not blossomed
# Image 84: Not blossomed
# Image 85: Not blossomed
# Image 86: Not blossomed
# Image 87: Not blossomed
# Image 88: Not blossomed
# Image 89: Not blossomed
# Image 90: Not blossomed
# Image 91: Not blossomed
# Image 92: Not blossomed
# Image 93: Not blossomed
# Image 94: Not blossomed
# Image 95: Not blossomed
# Image 96: Not blossomed
# Image 97: Not blossomed
# Image 98: Not blossomed
# Image 99: Not blossomed
# Image 100: Not blossomed
# Image 101: Not blossomed
# Image 102: Not blossomed
# Image 103: Not blossomed
# Image 104: Not blossomed
# Image 105: Not blossomed
# Image 106: Not blossomed
# Image 107: Not blossomed
# Image 108: Not blossomed
# Image 109: Not blossomed
# Image 110: Not blossomed
# Image 111: Not blossomed
# Image 112: Not blossomed
# Image 113: Not blossomed
# Image 114: Not blossomed
# Image 115: Not blossomed
# Image 116: Not blossomed
# Image 117: Not blossomed
# Image 118: Not blossomed
# Image 119: Not blossomed
# Image 120: Not blossomed
# Image 121: Not blossomed
# Image 122: Not blossomed
# Image 123: Not blossomed
# Image 124: Not blossomed
# Image 125: Not blossomed
# Image 126: Not blossomed
# Image 127: Not blossomed
# Image 128: Not blossomed
# Image 129: Not blossomed
# Image 130: Not blossomed
# Image 131: Not blossomed
# Image 132: Not blossomed
# Image 133: Not blossomed
# Image 134: Not blossomed
# Image 135: Not blossomed
# Image 136: Not blossomed
# Image 137: Not blossomed
# Image 138: Not blossomed
# Image 139: Not blossomed
# Image 140: Not blossomed
# Image 141: Not blossomed
# Image 142: Not blossomed
# Image 143: Not blossomed
# Image 144: Not blossomed
# Image 145: Not blossomed
# Image 146: Not blossomed
# Image 147: Not blossomed
# Image 148: Not blossomed
# Image 149: Not blossomed
# Image 150: Not blossomed
# Image 151: Not blossomed
# Image 152: Not blossomed
# Image 153: Not blossomed
# Image 154: Not blossomed
# Image 155: Not blossomed
# Image 156: Not blossomed
# Image 157: Not blossomed
# Image 158: Not blossomed
# Image 159: Not blossomed
# Image 160: Not blossomed
# Image 161: Not blossomed
# Image 162: Not blossomed
# Image 163: Not blossomed
# Image 164: Not blossomed
# Image 165: Not blossomed
# Image 166: Not blossomed
# Image 167: Not blossomed
# Image 168: Not blossomed
# Image 169: Not blossomed
# Image 170: Not blossomed
# Image 171: Not blossomed
# Image 172: Not blossomed
# Image 173: Not blossomed
# Image 174: Not blossomed
# Image 175: Not blossomed
# Image 176: Not blossomed
# Image 177: Not blossomed
# Image 178: Not blossomed
# Image 179: Not blossomed
# Image 180: Not blossomed
# Image 181: Not blossomed
# Image 182: Not blossomed
# Image 183: Not blossomed
# Image 184: Not blossomed
# Image 185: Not blossomed
# Image 186: Not blossomed
# Image 187: Not blossomed
# Image 188: Not blossomed
# Image 189: Not blossomed
# Image 190: Not blossomed
# Image 191: Not blossomed
# Image 192: Not blossomed
# Image 193: Not blossomed
# Image 194: Not blossomed
# Image 195: Not blossomed
# Image 196: Not blossomed
# Image 197: Not blossomed
# Image 198: Not blossomed
# Image 199: Not blossomed
# Image 200: Not blossomed
# Image 201: Not blossomed
# Image 202: Not blossomed
# Image 203: Not blossomed
# Image 204: Not blossomed
# Image 205: Not blossomed
# Image 206: Not blossomed
# Image 207: Not blossomed
# Image 208: Not blossomed
# Image 209: Not blossomed
# Image 210: Not blossomed
# Image 211: Not blossomed
# Image 212: Not blossomed
# Image 213: Not blossomed
# Image 214: Not blossomed
# Image 215: Not blossomed
# Image 216: Not blossomed
# Image 217: Not blossomed
# Image 218: Not blossomed
# Image 219: Not blossomed
# Image 220: Not blossomed
# Image 221: Not blossomed
# Image 222: Not blossomed
# Image 223: Not blossomed
# Image 224: Not blossomed
# Image 225: Not blossomed
# Image 226: Not blossomed
# Image 227: Not blossomed
# Image 228: Not blossomed
# Image 229: Not blossomed
# Image 230: Not blossomed
# Image 231: Not blossomed
# Image 232: Not blossomed
# Image 233: Not blossomed
# Image 234: Not blossomed
# Image 235: Not blossomed
# Image 236: Not blossomed
# Image 237: Not blossomed
# Image 238: Not blossomed
# Image 239: Not blossomed
# Image 240: Not blossomed
# Image 241: Not blossomed
# Image 242: Not blossomed
# Image 243: Not blossomed
# Image 244: Not blossomed
# Image 245: Not blossomed
# Image 246: Not blossomed
# Image 247: Not blossomed
# Image 248: Not blossomed
# Image 249: Not blossomed
# Image 250: Not blossomed
# Image 251: Not blossomed
# Image 252: Not blossomed
# Image 253: Not blossomed
# Image 254: Not blossomed
# Image 255: Not blossomed
# Image 256: Not blossomed
# Image 257: Not blossomed
# Image 258: Not blossomed
# Image 259: Not blossomed
# Image 260: Not blossomed
# Image 261: Not blossomed
# Image 262: Not blossomed
# Image 263: Not blossomed
# Image 264: Not blossomed
# Image 265: Not blossomed
# Image 266: Not blossomed
# Image 267: Not blossomed
# Image 268: Not blossomed
# Image 269: Not blossomed
# Image 270: Not blossomed
# Image 271: Not blossomed
# Image 272: Not blossomed
# Image 273: Not blossomed
# Image 274: Not blossomed
# Image 275: Not blossomed
# Image 276: Not blossomed
# Image 277: Not blossomed
# Image 278: Not blossomed
# Image 279: Not blossomed
# Image 280: Not blossomed
# Image 281: Not blossomed
# Image 282: Not blossomed
# Image 283: Not blossomed
# Image 284: Not blossomed
# Image 285: Not blossomed
# Image 286: Not blossomed
# Image 287: Not blossomed
# Image 288: Not blossomed
# Image 289: Not blossomed
# Image 290: Not blossomed
# Image 291: Not blossomed
# Image 292: Not blossomed
# Image 293: Not blossomed
# Image 294: Not blossomed
# Image 295: Not blossomed
# Image 296: Not blossomed
# Image 297: Not blossomed
# Image 298: Not blossomed
# Image 299: Not blossomed
# Image 300: Not blossomed
# Image 301: Not blossomed
# Image 302: Not blossomed
# Image 303: Not blossomed
# Image 304: Not blossomed
# Image 305: Not blossomed
# Image 306: Not blossomed
# Image 307: Not blossomed
# Image 308: Not blossomed
# Image 309: Not blossomed
# Image 310: Not blossomed
# Image 311: Not blossomed
# Image 312: Not blossomed
# Image 313: Not blossomed
# Image 314: Not blossomed
# Image 315: Not blossomed
# Image 316: Not blossomed
# Image 317: Not blossomed
# Image 318: Not blossomed
# Image 319: Not blossomed
# Image 320: Not blossomed
# Image 321: Not blossomed
# Image 322: Not blossomed
# Image 323: Not blossomed
# Image 324: Not blossomed
# Image 325: Not blossomed
# Image 326: Not blossomed
# Image 327: Not blossomed
# Image 328: Not blossomed
# Image 329: Not blossomed
# Image 330: Not blossomed
# Image 331: Not blossomed
# Image 332: Not blossomed
# Image 333: Not blossomed
# Image 334: Not blossomed
# Image 335: Not blossomed
# Image 336: Not blossomed
# Image 337: Not blossomed
# Image 338: Not blossomed
# Image 339: Not blossomed
# Image 340: Not blossomed
# Image 341: Not blossomed
# Image 342: Not blossomed
# Image 343: Not blossomed
# Image 344: Not blossomed
# Image 345: Not blossomed
# Image 346: Not blossomed
# Image 347: Not blossomed
# Image 348: Not blossomed
# Image 349: Not blossomed
# Image 350: Not blossomed
# Image 351: Not blossomed
# Image 352: Not blossomed
# Image 353: Not blossomed
# Image 354: Not blossomed
# Image 355: Not blossomed
# Image 356: Not blossomed
# Image 357: Not blossomed
# Image 358: Not blossomed
# Image 359: Not blossomed
# Image 360: Not blossomed
# Image 361: Not blossomed
# Image 362: Not blossomed
# Image 363: Not blossomed
# Image 364: Not blossomed
# Image 365: Not blossomed
# Image 366: Not blossomed
# Image 367: Not blossomed
# Image 368: Not blossomed
# Image 369: Not blossomed
# Image 370: Not blossomed
# Image 371: Not blossomed
# Image 372: Not blossomed
# Image 373: Not blossomed
# Image 374: Not blossomed
# Image 375: Not blossomed
# Image 376: Not blossomed
# Image 377: Not blossomed
# Image 378: Not blossomed
# Image 379: Not blossomed
# Image 380: Not blossomed
# Image 381: Not blossomed
# Image 382: Not blossomed
# Image 383: Not blossomed
# Image 384: Not blossomed
# Image 385: Not blossomed
# Image 386: Not blossomed
# Image 387: Not blossomed
# Image 388: Not blossomed
# Image 389: Not blossomed
# Image 390: Not blossomed
# Image 391: Not blossomed
# Image 392: Not blossomed
# Image 393: Not blossomed
# Image 394: Not blossomed
# Image 395: Not blossomed
# Image 396: Not blossomed
# Image 397: Not blossomed
# Image 398: Not blossomed
# Image 399: Not blossomed
# Image 400: Not blossomed
# Image 401: Not blossomed
# Image 402: Not blossomed
# Image 403: Not blossomed
# Image 404: Not blossomed
# Image 405: Not blossomed
# Image 406: Not blossomed
# Image 407: Not blossomed
# Image 408: Not blossomed
# Image 409: Not blossomed
# Image 410: Not blossomed
# Image 411: Not blossomed
# Image 412: Not blossomed
# Image 413: Not blossomed
# Image 414: Not blossomed
# Image 415: Not blossomed
# Image 416: Not blossomed
# Image 417: Not blossomed
# Image 418: Not blossomed
# Image 419: Not blossomed
# Image 420: Not blossomed
# Image 421: Not blossomed
# Image 422: Not blossomed
# Image 423: Not blossomed
# Image 424: Not blossomed
# Image 425: Not blossomed
# Image 426: Not blossomed
# Image 427: Not blossomed
# Image 428: Not blossomed
# Image 429: Not blossomed
# Image 430: Not blossomed
# Image 431: Not blossomed
# Image 432: Not blossomed
# Image 433: Not blossomed
# Image 434: Not blossomed
# Image 435: Not blossomed
# Image 436: Not blossomed
# Image 437: Not blossomed
# Image 438: Not blossomed
# Image 439: Not blossomed
# Image 440: Not blossomed
# Image 441: Not blossomed
# Image 442: Not blossomed
# Image 443: Not blossomed
# Image 444: Not blossomed
# Image 445: Not blossomed
# Image 446: Not blossomed
# Image 447: Not blossomed
# Image 448: Not blossomed
# Image 449: Not blossomed
# Image 450: Not blossomed
# Image 451: Not blossomed
# Image 452: Not blossomed
# Image 453: Not blossomed
# Image 454: Not blossomed
# Image 455: Not blossomed
# Image 456: Not blossomed
# Image 457: Not blossomed
# Image 458: Not blossomed
# Image 459: Not blossomed
# Image 460: Not blossomed
# Image 461: Not blossomed
# Image 462: Not blossomed
# Image 463: Not blossomed
# Image 464: Not blossomed
# Image 465: Not blossomed
# Image 466: Not blossomed
# Image 467: Not blossomed
# Image 468: Not blossomed
# Image 469: Not blossomed
# Image 470: Not blossomed
# Image 471: Not blossomed
# Image 472: Not blossomed
# Image 473: Not blossomed
# Image 474: Not blossomed
# Image 475: Not blossomed
# Image 476: Not blossomed
# Image 477: Not blossomed
# Image 478: Not blossomed
# Image 479: Not blossomed
# Image 480: Not blossomed
# Image 481: Not blossomed
# Image 482: Not blossomed
# Image 483: Not blossomed
# Image 484: Not blossomed
# Image 485: Not blossomed
# Image 486: Not blossomed
# Image 487: Not blossomed
# Image 488: Not blossomed
# Image 489: Not blossomed
# Image 490: Not blossomed
# Image 491: Not blossomed
# Image 492: Not blossomed
# Image 493: Not blossomed
# Image 494: Not blossomed
# Image 495: Not blossomed
# Image 496: Not blossomed
# Image 497: Not blossomed
# Image 498: Not blossomed
# Image 499: Not blossomed
# Image 500: Not blossomed
# Image 501: Not blossomed
# Image 502: Not blossomed
# Image 503: Not blossomed
# Image 504: Not blossomed
# Image 505: Not blossomed
# Image 506: Not blossomed
# Image 507: Not blossomed
# Image 508: Not blossomed
# Image 509: Not blossomed
# Image 510: Not blossomed
# Image 511: Not blossomed
# Image 512: Not blossomed
# Image 513: Not blossomed
# Image 514: Not blossomed
# Image 515: Not blossomed
# Image 516: Not blossomed
# Image 517: Not blossomed
# Image 518: Not blossomed
# Image 519: Not blossomed
# Image 520: Not blossomed
# Image 521: Not blossomed
# Image 522: Not blossomed
# Image 523: Not blossomed
# Image 524: Not blossomed
# Image 525: Not blossomed
# Image 526: Not blossomed
# Image 527: Not blossomed
# Image 528: Not blossomed
# Image 529: Not blossomed
# Image 530: Not blossomed
# Image 531: Not blossomed
# Image 532: Not blossomed
# Image 533: Not blossomed
# Image 534: Not blossomed
# Image 535: Not blossomed
# Image 536: Not blossomed
# Image 537: Not blossomed
# Image 538: Not blossomed
# Image 539: Not blossomed
# Image 540: Not blossomed
# Image 541: Not blossomed
# Image 542: Not blossomed
# Image 543: Not blossomed
# Image 544: Not blossomed
# Image 545: Not blossomed
# Image 546: Not blossomed
# Image 547: Not blossomed
# Image 548: Not blossomed
# Image 549: Not blossomed
# Image 550: Not blossomed
# Image 551: Not blossomed
# Image 552: Not blossomed
# Image 553: Not blossomed
# Image 554: Not blossomed
# Image 555: Not blossomed
# Image 556: Not blossomed
# Image 557: Not blossomed
# Image 558: Not blossomed
# Image 559: Not blossomed
# Image 560: Not blossomed
# Image 561: Not blossomed
# Image 562: Not blossomed
# Image 563: Not blossomed
# Image 564: Not blossomed
# Image 565: Not blossomed
# Image 566: Not blossomed
# Image 567: Not blossomed
# Image 568: Not blossomed
# Image 569: Not blossomed
# Image 570: Not blossomed
# Image 571: Not blossomed
# Image 572: Not blossomed
# Image 573: Not blossomed
# Image 574: Not blossomed
# Image 575: Not blossomed
# Image 576: Not blossomed
# Image 577: Not blossomed
# Image 578: Not blossomed
# Image 579: Not blossomed
# Image 580: Not blossomed
# Image 581: Not blossomed
# Image 582: Not blossomed
# Image 583: Not blossomed
# Image 584: Not blossomed
# Image 585: Not blossomed
# Image 586: Not blossomed
# Image 587: Not blossomed
# Image 588: Not blossomed
# Image 589: Not blossomed
# Image 590: Not blossomed
# Image 591: Not blossomed
# Image 592: Not blossomed
# Image 593: Not blossomed
# Image 594: Not blossomed
# Image 595: Not blossomed
# Image 596: Not blossomed
# Image 597: Not blossomed
# Image 598: Not blossomed
# Image 599: Not blossomed
# Image 600: Not blossomed
# Image 601: Not blossomed
# Image 602: Not blossomed
# Image 603: Not blossomed
# Image 604: Not blossomed
# Image 605: Not blossomed
# Image 606: Not blossomed
# Image 607: Not blossomed
# Image 608: Not blossomed
# Image 609: Not blossomed
# Image 610: Not blossomed
# Image 611: Not blossomed
# Image 612: Not blossomed
# Image 613: Not blossomed
# Image 614: Not blossomed
# Image 615: Not blossomed
# Image 616: Not blossomed
# Image 617: Not blossomed
# Image 618: Not blossomed
# Image 619: Not blossomed
# Image 620: Not blossomed
# Image 621: Not blossomed
# Image 622: Not blossomed
# Image 623: Not blossomed
# Image 624: Not blossomed
# Image 625: Not blossomed
# Image 626: Not blossomed
# Image 627: Not blossomed
# Image 628: Not blossomed
# Image 629: Not blossomed
# Image 630: Not blossomed
# Image 631: Not blossomed
# Image 632: Not blossomed
# Image 633: Not blossomed
# Image 634: Not blossomed
# Image 635: Not blossomed
# Image 636: Not blossomed
# Image 637: Not blossomed
# Image 638: Not blossomed
# Image 639: Not blossomed
# Image 640: Not blossomed
# Image 641: Not blossomed
# Image 642: Not blossomed
# Image 643: Not blossomed
# Image 644: Not blossomed
# Image 645: Not blossomed
# Image 646: Not blossomed
# Image 647: Not blossomed
# Image 648: Not blossomed
# Image 649: Not blossomed
# Image 650: Not blossomed
# Image 651: Not blossomed
# Image 652: Not blossomed
# Image 653: Not blossomed
# Image 654: Not blossomed
# Image 655: Not blossomed
# Image 656: Not blossomed
# Image 657: Not blossomed
# Image 658: Not blossomed
# Image 659: Not blossomed
# Image 660: Not blossomed
# Image 661: Not blossomed
# Image 662: Not blossomed
# Image 663: Not blossomed
# Image 664: Not blossomed
# Image 665: Not blossomed
# Image 666: Not blossomed
# Image 667: Not blossomed
# Image 668: Not blossomed
# Image 669: Not blossomed
# Image 670: Not blossomed
# Image 671: Not blossomed
# Image 672: Not blossomed
# Image 673: Not blossomed
# Image 674: Not blossomed
# Image 675: Not blossomed
# Image 676: Not blossomed
# Image 677: Not blossomed
# Image 678: Not blossomed
# Image 679: Not blossomed
# Image 680: Not blossomed
# Image 681: Not blossomed
# Image 682: Not blossomed
# Image 683: Not blossomed
# Image 684: Not blossomed
# Image 685: Not blossomed
# Image 686: Not blossomed
# Image 687: Not blossomed
# Image 688: Not blossomed
# Image 689: Not blossomed
# Image 690: Not blossomed
# Image 691: Not blossomed
# Image 692: Not blossomed
# Image 693: Not blossomed
# Image 694: Not blossomed
# Image 695: Not blossomed
# Image 696: Not blossomed
# Image 697: Not blossomed
# Image 698: Not blossomed
# Image 699: Not blossomed
# Image 700: Not blossomed
# Image 701: Not blossomed
# Image 702: Not blossomed
# Image 703: Not blossomed
# Image 704: Not blossomed
# Image 705: Not blossomed
# Image 706: Not blossomed
# Image 707: Not blossomed
# Image 708: Not blossomed
# Image 709: Not blossomed
# Image 710: Not blossomed
# Image 711: Not blossomed
# Image 712: Not blossomed
# Image 713: Not blossomed
# Image 714: Not blossomed
# Image 715: Not blossomed
# Image 716: Not blossomed
# Image 717: Not blossomed
# Image 718: Not blossomed
# Image 719: Not blossomed
# Image 720: Not blossomed
# Image 721: Not blossomed
# Image 722: Not blossomed
# Image 723: Not blossomed
# Image 724: Not blossomed
# Image 725: Not blossomed
# Image 726: Not blossomed
# Image 727: Not blossomed
# Image 728: Not blossomed
# Image 729: Not blossomed
# Image 730: Not blossomed
# Image 731: Not blossomed
# Image 732: Not blossomed

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score

# Confusion matrix 
cm_3 = confusion_matrix(test_labels_3, predictions_3_binary)
cm_2 = confusion_matrix(test_labels_2, predictions_2_binary)
#cm_1 = confusion_matrix(test_labels_1, predictions_1_binary)

print("Confusion matrix for 'blossomed_3' images:")
print(cm_3)

print("\nConfusion matrix for 'blossomed_2' images:")
print(cm_2)

#print("\nConfusion matrix for 'blossomed_1' images:")
#print(cm_1)

# Accuracy
accuracy_3 = accuracy_score(test_labels_3, predictions_3_binary)
accuracy_2 = accuracy_score(test_labels_2, predictions_2_binary)
#accuracy_1 = accuracy_score(test_labels_1, predictions_1_binary)

print(f"\nAccuracy for 'blossomed_3' images: {accuracy_3*100:.2f}%")
print(f"\nAccuracy for 'blossomed_2' images: {accuracy_2*100:.2f}%")
#print(f"\nAccuracy for 'blossomed_1' images: {accuracy_1*100:.2f}%")

# Precision
precision_3 = precision_score(test_labels_3, predictions_3_binary)
precision_2 = precision_score(test_labels_2, predictions_2_binary)
#precision_1 = precision_score(test_labels_1, predictions_1_binary)

print(f"\nPrecision for 'blossomed_3' images: {precision_3*100:.2f}%")
print(f"\nPrecision for 'blossomed_2' images: {precision_2*100:.2f}%")
#print(f"\nPrecision for 'blossomed_1' images: {precision_1*100:.2f}%")

# Recall
recall_3 = recall_score(test_labels_3, predictions_3_binary)
recall_2 = recall_score(test_labels_2, predictions_2_binary)
#recall_1 = recall_score(test_labels_1, predictions_1_binary)

print(f"\nRecall for 'blossomed_3' images: {recall_3*100:.2f}%")
print(f"\nRecall for 'blossomed_2' images: {recall_2*100:.2f}%")
#print(f"\nRecall for 'blossomed_1' images: {recall_1*100:.2f}%")
# Out:
# Confusion matrix for 'blossomed_3' images:
# [[  0   0]
#  [491   0]]
#
# Confusion matrix for 'blossomed_2' images:
# [[732]]
#
# Accuracy for 'blossomed_3' images: 0.00%
#
# Accuracy for 'blossomed_2' images: 100.00%
#
# Precision for 'blossomed_3' images: 0.00%
#
# Precision for 'blossomed_2' images: 0.00%
#
# Recall for 'blossomed_3' images: 0.00%
#
# Recall for 'blossomed_2' images: 0.00%
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
